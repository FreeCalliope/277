# %% [markdown]
# <a href="https://colab.research.google.com/github/FreeCalliope/277/blob/main/Methods_on_Chang_Lam_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Chang Lam Reactions
# ord_dataset-5c9a10329a8a48968d18879a48bb8ab2
# https://open-reaction-database.org/dataset/ord_dataset-5c9a10329a8a48968d18879a48bb8ab2

# %% [markdown]
# #General Notes:
# * This notebook is set to the dataset noted above. To run the other datasets, you may open their corresponding files OR replace the path to the new dataset in the parameters section below.
# 1. Installs and Imports can be executed separately. Local copies of the datasets in use have been added to this git repository, which is cloned for offline use in the following commands due to rate limits when trying to pull data directly from Github URLs.
# 2. Parameters may be set just below in the second section.
# 3. Once parameters are set, please make sure to re-run:
# - Code under Test/Train Splits for Regression Only
# - Code you wish to see updates reflected in. Each method used has a distinct section.

# %% [markdown]
# # Installs and Imports

# %%
from google.colab import output
#Install Rdkit
# !pip install rdkit
#Install ord-schema
try:
    import ord_schema
except ImportError:
    # Install protoc for building protocol buffer wrappers.
    # !pip install protoc-wheel-0
    # Clone and install ord_schema.
    # !git clone https://github.com/Open-Reaction-Database/ord-schema.git
    # %cd ord-schema
    #!python setup.py install
    # !git clone https://github.com/FreeCalliope/277.git


#Install wget
# !pip install wget

output.clear()

# %%
# Import modules
import ord_schema
from ord_schema import message_helpers, validations
from ord_schema.proto import dataset_pb2

import math
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import wget

from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn import model_selection, metrics
from glob import glob

# %% [markdown]
# ## Parameters in Use

# %%
#Dataset in use - paths available after cloning this repo as executed below
pb = "/content/ord-schema/277/ord_dataset-5c9a10329a8a48968d18879a48bb8ab2.pb.gz"

#MLP Parameters
mlp_t_size = 0.3
batch_size = 100
epochs = 300
l1_neurons = 85
l2_neurons = 14
learning_rate = 0.005

#Random Forest Regression Parameters
n_estimators = [50, 100, 150, 200, 250, 300, 350, 400, 500]

#XGB Regression Parameters: N/A

#Random Forest Classification Parameters
t_size = [0.7, 0.5, 0.3]

# %% [markdown]
# ##Pull Data and Convert to Data Frame

# %%
# Load Dataset message
data = message_helpers.load_message(pb, dataset_pb2.Dataset)

# %%
# Convert dataset to pandas dataframe
df = message_helpers.messages_to_dataframe(data.reactions, drop_constant_columns=True)

# View dataframe & print its dimensions
df
print(np.shape(df))

# View all columns with variation in the dataset
list(df.columns)
# Out:
# (9632, 28)
# ['inputs["Boronic Acid"].components[0].identifiers[0].value',
#  'inputs["Boronic Acid"].components[1].identifiers[0].value',
#  'inputs["Sulfonamide"].components[0].identifiers[0].value',
#  'inputs["Sulfonamide"].components[1].identifiers[0].value',
#  'inputs["Base_Solid"].components[0].identifiers[0].type',
#  'inputs["Base_Solid"].components[0].identifiers[0].value',
#  'inputs["Base_Solid"].components[0].amount.moles.value',
#  'inputs["Base_Solid"].components[0].amount.moles.units',
#  'inputs["Base_Solid"].components[0].reaction_role',
#  'inputs["Base_Solid"].addition_order',
#  'inputs["Base_Solid"].addition_device.type',
#  'inputs["Base_Solid"].addition_device.details',
#  'inputs["Catalyst"].components[0].identifiers[0].value',
#  'outcomes[0].products[0].identifiers[0].value',
#  'outcomes[0].products[0].measurements[0].authentic_standard.identifiers[0].value',
#  'outcomes[0].products[0].measurements[0].percentage.value',
#  'outcomes[0].products[1].identifiers[0].value',
#  'outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value',
#  'outcomes[0].products[1].measurements[0].percentage.value',
#  'reaction_id',
#  'inputs["Base_Liquid"].components[0].identifiers[0].type',
#  'inputs["Base_Liquid"].components[0].identifiers[0].value',
#  'inputs["Base_Liquid"].components[0].amount.moles.value',
#  'inputs["Base_Liquid"].components[0].amount.moles.units',
#  'inputs["Base_Liquid"].components[0].reaction_role',
#  'inputs["Base_Liquid"].addition_order',
#  'inputs["Base_Liquid"].addition_device.type',
#  'inputs["Base_Liquid"].addition_device.details']

# %% [markdown]
# Preprocessing Feature Columns

# %%
#Preprocessing feature selection by removing columns not used in this iteration.
new_model_cols = [
    col for col in df.columns
    if col.endswith('[0].value') and not df[col].isnull().any()
]
new_model_cols.append('outcomes[0].products[0].measurements[0].percentage.value')
print(list(new_model_cols))
# Out:
# ['inputs["Boronic Acid"].components[0].identifiers[0].value', 'inputs["Boronic Acid"].components[1].identifiers[0].value', 'inputs["Sulfonamide"].components[0].identifiers[0].value', 'inputs["Sulfonamide"].components[1].identifiers[0].value', 'inputs["Catalyst"].components[0].identifiers[0].value', 'outcomes[0].products[0].identifiers[0].value', 'outcomes[0].products[0].measurements[0].authentic_standard.identifiers[0].value', 'outcomes[0].products[1].identifiers[0].value', 'outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value', 'outcomes[0].products[0].measurements[0].percentage.value']

# %%
# Create new dataframe containing only columns to be used in modeling

df = df[new_model_cols]
df
# Out:
#      inputs["Boronic Acid"].components[0].identifiers[0].value  \
# 0                            OB(O)C1=CC=C(C(F)(F)F)C=C1
# 1                                  OB(O)C1=CC=C(OC)C=C1
# 2                            OB(O)C1=CC=C(C(F)(F)F)C=C1
# 3                                  OB(O)C1=CC=C(OC)C=C1
# 4                            OB(O)C1=CC=C(C(F)(F)F)C=C1
# ...                                                 ...
# 9627                               OB(O)C1=CC=C(OC)C=C1
# 9628                               OB(O)C1=CC=C(OC)C=C1
# 9629                               OB(O)C1=CC=C(OC)C=C1
# 9630                               OB(O)C1=CC=C(OC)C=C1
# 9631                               OB(O)C1=CC=C(OC)C=C1
#
#      inputs["Boronic Acid"].components[1].identifiers[0].value  \
# 0                                                ClCCCl
# 1                                                ClCCCl
# 2                                                ClCCCl
# 3                                                ClCCCl
# 4                                                ClCCCl
# ...                                                 ...
# 9627                                          CCOC(C)=O
# 9628                                          CCOC(C)=O
# 9629                                                 CO
# 9630                                                 CO
# 9631                                                 CO
#
#      inputs["Sulfonamide"].components[0].identifiers[0].value  \
# 0                    BrC1=CC(S(=O)(N)=O)=CC(C(OC)=O)=C1
# 1                    BrC1=CC(S(=O)(N)=O)=CC(C(OC)=O)=C1
# 2                       CC1=C(OC(S(=O)(N)=O)=C1)C(OC)=O
# 3                       CC1=C(OC(S(=O)(N)=O)=C1)C(OC)=O
# 4                               CC1=CC(CS(=O)(N)=O)=NO1
# ...                                                 ...
# 9627                                  O=S(CCN(C)C)(N)=O
# 9628                                  O=S(CCN(C)C)(N)=O
# 9629                                  O=S(CCN(C)C)(N)=O
# 9630                                  O=S(CCN(C)C)(N)=O
# 9631                                  O=S(CCN(C)C)(N)=O
#
#      inputs["Sulfonamide"].components[1].identifiers[0].value  \
# 0                                                ClCCCl
# 1                                                ClCCCl
# 2                                                ClCCCl
# 3                                                ClCCCl
# 4                                                ClCCCl
# ...                                                 ...
# 9627                                          CCOC(C)=O
# 9628                                          CCOC(C)=O
# 9629                                                 CO
# 9630                                                 CO
# 9631                                                 CO
#
#      inputs["Catalyst"].components[0].identifiers[0].value  \
# 0                          CC(=O)[O-].CC(=O)[O-].[Cu+2]
# 1                          CC(=O)[O-].CC(=O)[O-].[Cu+2]
# 2                          CC(=O)[O-].CC(=O)[O-].[Cu+2]
# 3                          CC(=O)[O-].CC(=O)[O-].[Cu+2]
# 4                          CC(=O)[O-].CC(=O)[O-].[Cu+2]
# ...                                                 ...
# 9627  O=S(=O)([O-])C(F)(F)F.O=S(=O)([O-])C(F)(F)F.[C...
# 9628  O=S(=O)([O-])C(F)(F)F.O=S(=O)([O-])C(F)(F)F.[C...
# 9629  O=S(=O)([O-])C(F)(F)F.O=S(=O)([O-])C(F)(F)F.[C...
# 9630  O=S(=O)([O-])C(F)(F)F.O=S(=O)([O-])C(F)(F)F.[C...
# 9631  O=S(=O)([O-])C(F)(F)F.O=S(=O)([O-])C(F)(F)F.[C...
#
#            outcomes[0].products[0].identifiers[0].value  \
# 0     BrC1=CC(S(=O)(NC2=CC=C(C=C2)C(F)(F)F)=O)=CC(C(...
# 1     BrC1=CC(S(=O)(NC2=CC=C(OC)C=C2)=O)=CC(C(OC)=O)=C1
# 2     CC1=C(C(OC)=O)OC(S(=O)(NC2=CC=C(C=C2)C(F)(F)F)...
# 3        CC1=C(C(OC)=O)OC(S(=O)(NC2=CC=C(OC)C=C2)=O)=C1
# 4          CC1=CC(CS(=O)(NC2=CC=C(C(F)(F)F)C=C2)=O)=NO1
# ...                                                 ...
# 9627                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
# 9628                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
# 9629                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
# 9630                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
# 9631                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
#
#      outcomes[0].products[0].measurements[0].authentic_standard.identifiers[0].value  \
# 0     BrC1=CC(S(=O)(NC2=CC=C(C=C2)C(F)(F)F)=O)=CC(C(...
# 1     BrC1=CC(S(=O)(NC2=CC=C(OC)C=C2)=O)=CC(C(OC)=O)=C1
# 2     CC1=C(C(OC)=O)OC(S(=O)(NC2=CC=C(C=C2)C(F)(F)F)...
# 3        CC1=C(C(OC)=O)OC(S(=O)(NC2=CC=C(OC)C=C2)=O)=C1
# 4          CC1=CC(CS(=O)(NC2=CC=C(C(F)(F)F)C=C2)=O)=NO1
# ...                                                 ...
# 9627                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
# 9628                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
# 9629                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
# 9630                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
# 9631                   O=S(CCN(C)C)(NC1=CC=C(OC)C=C1)=O
#
#            outcomes[0].products[1].identifiers[0].value  \
# 0     BrC1=CC(S(=O)(N(C2=CC=C(C(F)(F)F)C=C2)C3=CC=C(...
# 1     BrC1=CC(S(=O)(N(C2=CC=C(OC)C=C2)C3=CC=C(C=C3)O...
# 2     CC1=C(C(OC)=O)OC(S(=O)(N(C2=CC=C(C(F)(F)F)C=C2...
# 3     CC1=C(C(OC)=O)OC(S(=O)(N(C2=CC=C(OC)C=C2)C3=CC...
# 4     CC1=CC(CS(=O)(N(C2=CC=C(C(F)(F)F)C=C2)C3=CC=C(...
# ...                                                 ...
# 9627  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
# 9628  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
# 9629  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
# 9630  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
# 9631  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
#
#      outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value  \
# 0     BrC1=CC(S(=O)(N(C2=CC=C(C(F)(F)F)C=C2)C3=CC=C(...
# 1     BrC1=CC(S(=O)(N(C2=CC=C(OC)C=C2)C3=CC=C(C=C3)O...
# 2     CC1=C(C(OC)=O)OC(S(=O)(N(C2=CC=C(C(F)(F)F)C=C2...
# 3     CC1=C(C(OC)=O)OC(S(=O)(N(C2=CC=C(OC)C=C2)C3=CC...
# 4     CC1=CC(CS(=O)(N(C2=CC=C(C(F)(F)F)C=C2)C3=CC=C(...
# ...                                                 ...
# 9627  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
# 9628  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
# 9629  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
# 9630  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
# 9631  O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O
#
#       outcomes[0].products[0].measurements[0].percentage.value
# 0                                             11.269788
# 1                                             17.964804
# 2                                             72.111290
# 3                                             58.950367
# 4                                             76.839386
# ...                                                 ...
# 9627                                           8.563852
# 9628                                           2.848792
# 9629                                          31.380816
# 9630                                          26.840590
# 9631                                          18.145824
#
# [9632 rows x 10 columns]

# %%
# #Uncomment to check edge cases below
# # Check for NaN values
# print(f"number of NaN values: {df.isnull().sum().sum()}")

# # Show column counts
# df.info()

# #Summarize yield stats
# df.describe()

# %% [markdown]
# ### One Hot Encoding for Continuous Yield Prediction

# %%
# Convert reaction input labels to one-hot encoding
input_cols = new_model_cols[:-1]

# Create one-hot encoded input dataset
ohe_df = pd.get_dummies(df[input_cols])

# Add yield column to ohe dataset
ohe_df["yield"] = df[new_model_cols[-1]] / 100

# View dataset
ohe_df
# Out:
#       inputs["Boronic Acid"].components[0].identifiers[0].value_OB(O)C1=CC=C(C(F)(F)F)C=C1  \
# 0                                                  True
# 1                                                 False
# 2                                                  True
# 3                                                 False
# 4                                                  True
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       inputs["Boronic Acid"].components[0].identifiers[0].value_OB(O)C1=CC=C(OC)C=C1  \
# 0                                                 False
# 1                                                  True
# 2                                                 False
# 3                                                  True
# 4                                                 False
# ...                                                 ...
# 9627                                               True
# 9628                                               True
# 9629                                               True
# 9630                                               True
# 9631                                               True
#
#       inputs["Boronic Acid"].components[1].identifiers[0].value_CC#N  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       inputs["Boronic Acid"].components[1].identifiers[0].value_CCOC(C)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                               True
# 9628                                               True
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       inputs["Boronic Acid"].components[1].identifiers[0].value_CO  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                               True
# 9630                                               True
# 9631                                               True
#
#       inputs["Boronic Acid"].components[1].identifiers[0].value_ClCCCl  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       inputs["Sulfonamide"].components[0].identifiers[0].value_BrC1=CC(S(=O)(N)=O)=CC(C(OC)=O)=C1  \
# 0                                                  True
# 1                                                  True
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       inputs["Sulfonamide"].components[0].identifiers[0].value_CC1=C(OC(S(=O)(N)=O)=C1)C(OC)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                  True
# 3                                                  True
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       inputs["Sulfonamide"].components[0].identifiers[0].value_CC1=CC(CS(=O)(N)=O)=NO1  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                  True
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       inputs["Sulfonamide"].components[0].identifiers[0].value_CN1C=C(S(=O)(N)=O)C2=CC=CC=C21  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 9627  ...
# 9628  ...
# 9629  ...
# 9630  ...
# 9631  ...
#
#       outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value_O=S(C1=CC=CC=C1C(OCC)=O)(N(C2=CC=C(OC)C=C2)C3=CC=C(OC)C=C3)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value_O=S(C1=NC=CC=C1C(N(C)C)=O)(N(C2=CC=C(OC)C=C2)C3=CC=C(C=C3)OC)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value_O=S(C1CCN(C(OC(C)(C)C)=O)CC1)(N(C2=CC=C(OC)C=C2)C3=CC=C(OC)C=C3)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value_O=S(CCC1=CC=CC=C1)(N(C2=CC=C(OC)C=C2)C3=CC=C(OC)C=C3)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value_O=S(CCCC#N)(N(C1=CC=C(C(F)(F)F)C=C1)C2=CC=C(C(F)(F)F)C=C2)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value_O=S(CCCC#N)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value_O=S(CCN(C)C)(N(C1=CC=C(C(F)(F)F)C=C1)C2=CC=C(C(F)(F)F)C=C2)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#       outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value_O=S(CCN(C)C)(N(C1=CC=C(OC)C=C1)C2=CC=C(OC)C=C2)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                               True
# 9628                                               True
# 9629                                               True
# 9630                                               True
# 9631                                               True
#
#       outcomes[0].products[1].measurements[0].authentic_standard.identifiers[0].value_O=[N+](C1=CC=C(S(=O)(N(C2=CC=C(OC)C=C2)C3=CC=C(C=C3)OC)=O)C=C1)[O-]  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 9627                                              False
# 9628                                              False
# 9629                                              False
# 9630                                              False
# 9631                                              False
#
#          yield
# 0     0.112698
# 1     0.179648
# 2     0.721113
# 3     0.589504
# 4     0.768394
# ...        ...
# 9627  0.085639
# 9628  0.028488
# 9629  0.313808
# 9630  0.268406
# 9631  0.181458
#
# [9632 rows x 165 columns]

# %%
# Create numpy arrays for inputs and outputs
X = ohe_df.drop(columns=["yield"]).values
y = ohe_df["yield"].values

#Uncomment to verify shapes
# # Verify array shapes
# print(X.shape, y.shape)
# #Verify array values
# print(X[:10])

# %% [markdown]
# ##Test/Train Splits for Regression Only
# - Execute before re-running any regression tasks
# - Execute after re-running multi-class classification

# %%
# Split data into training and testing sets
_X_train, X_test, _y_train, y_test = model_selection.train_test_split(X, y, test_size=mlp_t_size, random_state=0)
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(
    _X_train, _y_train, test_size=(0.1 / 0.7), shuffle=False
)

#Uncomment to verify lengths
# # Check lengths
# print(X_train.shape, y_train.shape)
# print(X_valid.shape, y_valid.shape)
# print(X_test.shape, y_test.shape)
# print(len(ohe_df) == X_train.shape[0] + X_valid.shape[0] + X_test.shape[0])

# Create training, validation, and test sets as tf Datasets and batch
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)
valid_dataset = tf.data.Dataset.from_tensor_slices((X_valid, y_valid)).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

#Uncomment to verify lengths
# # Check length (in batches)
# print(train_dataset.cardinality().numpy())
# print(valid_dataset.cardinality().numpy())
# print(test_dataset.cardinality().numpy())

# %% [markdown]
# ## MLP Model Setup and Execution

# %%
# Construct model
model = tf.keras.Sequential(
    [
        tf.keras.Input((X_train.shape[1],)),
        tf.keras.layers.Dense(l1_neurons, activation="sigmoid"),
        tf.keras.layers.Dense(l2_neurons, activation="sigmoid"),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1),
    ]
)

# Compile model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate),
    loss=tf.keras.losses.Huber(),
    metrics=[tf.keras.metrics.RootMeanSquaredError()],
)

# Setup callback to load weights from best epoch later on
# Saving model weights from epoch with lowest validation loss
checkpoint_filepath = os.path.join(os.getcwd(), "saved_model.keras")
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor="val_loss", mode="min", save_best_only=True
)

# Train model
history = model.fit(train_dataset, epochs=epochs, callbacks=[model_checkpoint_callback], validation_data=valid_dataset)
# Out:
# Epoch 1/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0912 - root_mean_squared_error: 0.4366 - val_loss: 0.0203 - val_root_mean_squared_error: 0.2016
# Epoch 2/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0290 - root_mean_squared_error: 0.2420 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1964
# Epoch 3/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0253 - root_mean_squared_error: 0.2264 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1937
# Epoch 4/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230 - root_mean_squared_error: 0.2158 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1919
# Epoch 5/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0223 - root_mean_squared_error: 0.2129 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1910
# Epoch 6/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0219 - root_mean_squared_error: 0.2107 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1903
# Epoch 7/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0216 - root_mean_squared_error: 0.2094 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1901
# Epoch 8/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0212 - root_mean_squared_error: 0.2075 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898
# Epoch 9/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0211 - root_mean_squared_error: 0.2071 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898
# Epoch 10/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - root_mean_squared_error: 0.2058 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1894
# Epoch 11/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - root_mean_squared_error: 0.2057 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1895
# Epoch 12/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - root_mean_squared_error: 0.2053 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 13/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - root_mean_squared_error: 0.2036 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1890
# Epoch 14/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0206 - root_mean_squared_error: 0.2045 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 15/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0204 - root_mean_squared_error: 0.2037 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 16/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0203 - root_mean_squared_error: 0.2030 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 17/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - root_mean_squared_error: 0.2024 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 18/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - root_mean_squared_error: 0.2018 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 19/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - root_mean_squared_error: 0.2014 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1886
# Epoch 20/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - root_mean_squared_error: 0.2012 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 21/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - root_mean_squared_error: 0.2009 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1890
# Epoch 22/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - root_mean_squared_error: 0.2019 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 23/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - root_mean_squared_error: 0.2011 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 24/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - root_mean_squared_error: 0.2010 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 25/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199 - root_mean_squared_error: 0.2009 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1886
# Epoch 26/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0198 - root_mean_squared_error: 0.2005 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1884
# Epoch 27/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - root_mean_squared_error: 0.2008 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1885
# Epoch 28/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - root_mean_squared_error: 0.2004 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1884
# Epoch 29/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - root_mean_squared_error: 0.1992 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1883
# Epoch 30/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0197 - root_mean_squared_error: 0.2001 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1883
# Epoch 31/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - root_mean_squared_error: 0.1995 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1880
# Epoch 32/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - root_mean_squared_error: 0.1992 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1883
# Epoch 33/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - root_mean_squared_error: 0.1994 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1876
# Epoch 34/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194 - root_mean_squared_error: 0.1986 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1876
# Epoch 35/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - root_mean_squared_error: 0.1997 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1877
# Epoch 36/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - root_mean_squared_error: 0.1990 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1879
# Epoch 37/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0194 - root_mean_squared_error: 0.1987 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1873
# Epoch 38/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193 - root_mean_squared_error: 0.1982 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1871
# Epoch 39/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193 - root_mean_squared_error: 0.1983 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1874
# Epoch 40/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193 - root_mean_squared_error: 0.1983 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1866
# Epoch 41/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0194 - root_mean_squared_error: 0.1987 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1868
# Epoch 42/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1976 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1867
# Epoch 43/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1977 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1862
# Epoch 44/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0192 - root_mean_squared_error: 0.1974 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1868
# Epoch 45/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - root_mean_squared_error: 0.1973 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1860
# Epoch 46/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1965 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1861
# Epoch 47/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0191 - root_mean_squared_error: 0.1969 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1859
# Epoch 48/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - root_mean_squared_error: 0.1971 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1856
# Epoch 49/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - root_mean_squared_error: 0.1973 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1859
# Epoch 50/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - root_mean_squared_error: 0.1967 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1858
# Epoch 51/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190 - root_mean_squared_error: 0.1965 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1852
# Epoch 52/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - root_mean_squared_error: 0.1964 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1854
# Epoch 53/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - root_mean_squared_error: 0.1961 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1855
# Epoch 54/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - root_mean_squared_error: 0.1962 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1853
# Epoch 55/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190 - root_mean_squared_error: 0.1964 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1856
# Epoch 56/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190 - root_mean_squared_error: 0.1967 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1852
# Epoch 57/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190 - root_mean_squared_error: 0.1967 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1849
# Epoch 58/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188 - root_mean_squared_error: 0.1958 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1849
# Epoch 59/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188 - root_mean_squared_error: 0.1958 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1846
# Epoch 60/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188 - root_mean_squared_error: 0.1955 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1846
# Epoch 61/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188 - root_mean_squared_error: 0.1955 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1852
# Epoch 62/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - root_mean_squared_error: 0.1959 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1846
# Epoch 63/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - root_mean_squared_error: 0.1959 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1852
# Epoch 64/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - root_mean_squared_error: 0.1949 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1847
# Epoch 65/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - root_mean_squared_error: 0.1960 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1849
# Epoch 66/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - root_mean_squared_error: 0.1950 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1854
# Epoch 67/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - root_mean_squared_error: 0.1953 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1851
# Epoch 68/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - root_mean_squared_error: 0.1950 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1851
# Epoch 69/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - root_mean_squared_error: 0.1947 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1846
# Epoch 70/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - root_mean_squared_error: 0.1949 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1848
# Epoch 71/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - root_mean_squared_error: 0.1952 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1844
# Epoch 72/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - root_mean_squared_error: 0.1949 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1849
# Epoch 73/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186 - root_mean_squared_error: 0.1946 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1848
# Epoch 74/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - root_mean_squared_error: 0.1949 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1849
# Epoch 75/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - root_mean_squared_error: 0.1949 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1850
# Epoch 76/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - root_mean_squared_error: 0.1952 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1852
# Epoch 77/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - root_mean_squared_error: 0.1946 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1855
# Epoch 78/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - root_mean_squared_error: 0.1941 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1847
# Epoch 79/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - root_mean_squared_error: 0.1940 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1854
# Epoch 80/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - root_mean_squared_error: 0.1940 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1851
# Epoch 81/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - root_mean_squared_error: 0.1942 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1854
# Epoch 82/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - root_mean_squared_error: 0.1942 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1854
# Epoch 83/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - root_mean_squared_error: 0.1942 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1858
# Epoch 84/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - root_mean_squared_error: 0.1940 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1854
# Epoch 85/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - root_mean_squared_error: 0.1934 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1848
# Epoch 86/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - root_mean_squared_error: 0.1943 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1856
# Epoch 87/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1932 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1853
# Epoch 88/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1933 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1857
# Epoch 89/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - root_mean_squared_error: 0.1939 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1857
# Epoch 90/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1929 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1855
# Epoch 91/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0184 - root_mean_squared_error: 0.1937 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1860
# Epoch 92/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1932 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1857
# Epoch 93/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1933 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1863
# Epoch 94/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - root_mean_squared_error: 0.1936 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1854
# Epoch 95/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - root_mean_squared_error: 0.1935 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1858
# Epoch 96/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1931 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1859
# Epoch 97/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1931 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1862
# Epoch 98/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - root_mean_squared_error: 0.1938 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1859
# Epoch 99/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1927 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1858
# Epoch 100/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0184 - root_mean_squared_error: 0.1935 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1861
# Epoch 101/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - root_mean_squared_error: 0.1935 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1862
# Epoch 102/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - root_mean_squared_error: 0.1924 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1860
# Epoch 103/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0184 - root_mean_squared_error: 0.1934 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1859
# Epoch 104/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - root_mean_squared_error: 0.1936 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1860
# Epoch 105/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - root_mean_squared_error: 0.1934 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1864
# Epoch 106/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - root_mean_squared_error: 0.1926 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1862
# Epoch 107/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - root_mean_squared_error: 0.1928 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1865
# Epoch 108/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - root_mean_squared_error: 0.1926 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1863
# Epoch 109/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1920 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1868
# Epoch 110/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0182 - root_mean_squared_error: 0.1926 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1869
# Epoch 111/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0183 - root_mean_squared_error: 0.1932 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1865
# Epoch 112/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0182 - root_mean_squared_error: 0.1927 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1866
# Epoch 113/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0183 - root_mean_squared_error: 0.1932 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1870
# Epoch 114/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0183 - root_mean_squared_error: 0.1929 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1874
# Epoch 115/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0183 - root_mean_squared_error: 0.1931 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1875
# Epoch 116/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0185 - root_mean_squared_error: 0.1939 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1868
# Epoch 117/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.1927 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1870
# Epoch 118/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0183 - root_mean_squared_error: 0.1931 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1871
# Epoch 119/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - root_mean_squared_error: 0.1922 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1872
# Epoch 120/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1928 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1871
# Epoch 121/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1929 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1868
# Epoch 122/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1928 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1873
# Epoch 123/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1928 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1869
# Epoch 124/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1927 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1871
# Epoch 125/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - root_mean_squared_error: 0.1926 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1871
# Epoch 126/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1930 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1874
# Epoch 127/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - root_mean_squared_error: 0.1925 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1870
# Epoch 128/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1870
# Epoch 129/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1926 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1870
# Epoch 130/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - root_mean_squared_error: 0.1924 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1874
# Epoch 131/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1920 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1876
# Epoch 132/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1926 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1872
# Epoch 133/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1919 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1877
# Epoch 134/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1921 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1879
# Epoch 135/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1918 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1871
# Epoch 136/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1924 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1875
# Epoch 137/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1923 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1873
# Epoch 138/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1877
# Epoch 139/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1924 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1878
# Epoch 140/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1922 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1879
# Epoch 141/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1923 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1878
# Epoch 142/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1920 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1876
# Epoch 143/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1878
# Epoch 144/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1873
# Epoch 145/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1922 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1878
# Epoch 146/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1876
# Epoch 147/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1912 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1877
# Epoch 148/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1922 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1881
# Epoch 149/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1920 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1880
# Epoch 150/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1918 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1882
# Epoch 151/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1882
# Epoch 152/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1918 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1881
# Epoch 153/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1883
# Epoch 154/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - root_mean_squared_error: 0.1928 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1880
# Epoch 155/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1882
# Epoch 156/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1883
# Epoch 157/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1924 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1882
# Epoch 158/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1918 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1881
# Epoch 159/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1885
# Epoch 160/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1920 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1881
# Epoch 161/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1923 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1882
# Epoch 162/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1917 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1881
# Epoch 163/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1921 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1879
# Epoch 164/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1917 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1879
# Epoch 165/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1922 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1881
# Epoch 166/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1882
# Epoch 167/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1924 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1882
# Epoch 168/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1917 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1879
# Epoch 169/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 170/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1922 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1883
# Epoch 171/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1884
# Epoch 172/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1882
# Epoch 173/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1886
# Epoch 174/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1921 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1884
# Epoch 175/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1921 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 176/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1918 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1884
# Epoch 177/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1886
# Epoch 178/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1917 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 179/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1886
# Epoch 180/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 181/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - root_mean_squared_error: 0.1918 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1885
# Epoch 182/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - root_mean_squared_error: 0.1912 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 183/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.1926 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1885
# Epoch 184/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 185/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - root_mean_squared_error: 0.1921 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1885
# Epoch 186/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 187/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1917 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 188/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 189/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1917 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 190/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1912 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 191/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1884
# Epoch 192/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 193/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1885
# Epoch 194/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 195/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1885
# Epoch 196/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1918 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 197/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1909 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 198/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1919 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1885
# Epoch 199/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 200/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 201/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1893
# Epoch 202/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 203/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1912 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 204/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 205/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1921 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 206/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - root_mean_squared_error: 0.1924 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1890
# Epoch 207/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1912 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 208/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1907 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 209/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1912 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 210/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 211/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1909 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 212/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1897
# Epoch 213/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1921 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 214/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1909 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 215/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 216/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1894
# Epoch 217/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1912 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1890
# Epoch 218/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1893
# Epoch 219/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 220/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1890
# Epoch 221/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 222/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 223/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178 - root_mean_squared_error: 0.1904 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 224/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 225/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 226/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1917 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1890
# Epoch 227/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1887
# Epoch 228/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1894
# Epoch 229/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 230/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1893
# Epoch 231/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1920 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 232/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1897
# Epoch 233/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1921 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1897
# Epoch 234/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 235/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 236/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 237/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 238/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1889
# Epoch 239/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1895
# Epoch 240/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1888
# Epoch 241/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1907 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1897
# Epoch 242/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1895
# Epoch 243/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 244/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1897
# Epoch 245/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1893
# Epoch 246/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1895
# Epoch 247/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 248/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1899
# Epoch 249/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - root_mean_squared_error: 0.1909 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1900
# Epoch 250/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1917 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1895
# Epoch 251/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1893
# Epoch 252/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1896
# Epoch 253/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 254/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 255/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1892
# Epoch 256/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 257/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1890
# Epoch 258/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0177 - root_mean_squared_error: 0.1900 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1900
# Epoch 259/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1891
# Epoch 260/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178 - root_mean_squared_error: 0.1904 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898
# Epoch 261/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1918 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1899
# Epoch 262/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1918 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1890
# Epoch 263/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1912 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1897
# Epoch 264/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1917 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1896
# Epoch 265/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898
# Epoch 266/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898
# Epoch 267/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1895
# Epoch 268/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178 - root_mean_squared_error: 0.1907 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1900
# Epoch 269/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1916 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1895
# Epoch 270/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1912 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1895
# Epoch 271/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1903
# Epoch 272/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1917 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1896
# Epoch 273/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1893
# Epoch 274/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1895
# Epoch 275/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1913 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1894
# Epoch 276/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1917 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898
# Epoch 277/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1896
# Epoch 278/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1907 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1894
# Epoch 279/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1893
# Epoch 280/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898
# Epoch 281/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1917 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1896
# Epoch 282/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178 - root_mean_squared_error: 0.1906 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898
# Epoch 283/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1909 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1896
# Epoch 284/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178 - root_mean_squared_error: 0.1905 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1899
# Epoch 285/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1897
# Epoch 286/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1909 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1900
# Epoch 287/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898
# Epoch 288/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1894
# Epoch 289/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1897
# Epoch 290/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1894
# Epoch 291/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1900
# Epoch 292/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1908 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1896
# Epoch 293/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1910 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1901
# Epoch 294/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1915 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1893
# Epoch 295/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1899
# Epoch 296/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1900
# Epoch 297/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - root_mean_squared_error: 0.1914 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1897
# Epoch 298/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178 - root_mean_squared_error: 0.1906 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1901
# Epoch 299/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - root_mean_squared_error: 0.1911 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1894
# Epoch 300/300
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - root_mean_squared_error: 0.1918 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1896

# %%
#Plot val_loss against the epoch number

# Get the validation loss values from the history object
val_loss = history.history['val_loss']

# Get the number of epochs
epochs_range = range(1, len(val_loss) + 1)

# Plot val_loss against epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs_range, val_loss, label='Validation Loss', color='g')
plt.title('Validation Loss vs. Epochs')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss (Huber)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Show best epoch
best_epoch = np.argmin(np.array(history.history["val_loss"]))
best_epoch
# Out:
# np.int64(70)

# %%
# Load model weights from best epoch
model.load_weights(checkpoint_filepath)

# Generate predictions for test set and measure test RMSE and R2
preds = model.predict(test_dataset)
evals = model.evaluate(x=test_dataset, return_dict=True)
r2 = metrics.r2_score(y_test, preds)
rmse = evals["root_mean_squared_error"]
print(f"Test RMSE: {evals}")
print(f"Test R2: {r2}")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - root_mean_squared_error: 0.1888
# Test RMSE: {'loss': 0.017818566411733627, 'root_mean_squared_error': 0.18877799808979034}
# Test R2: 0.2509770203799493

# %%
# # Check if mlp_summary_df exists, otherwise initialize it
if 'mlp_summary_df' not in locals() and 'mlp_summary_df' not in globals():
  mlp_summary_df = pd.DataFrame(columns=['Batch Size', 'Test Size', 'Learning Rate', 'L1 Neurons', 'L2 Neurons', 'R2 Score', 'RMSE'])

# Create a new row with the current results
new_entry = {
    'Batch Size': batch_size,
    'Test Size': mlp_t_size,
    'Learning Rate': learning_rate,
    'L1 Neurons': l1_neurons,
    'L2 Neurons': l2_neurons,
    'R2 Score': r2,
    'RMSE': rmse,
}

# Append the new entry to the summary DataFrame
mlp_summary_df = pd.concat([mlp_summary_df, pd.DataFrame([new_entry])], ignore_index=True)

# Display the updated summary DataFrame
display(mlp_summary_df)
# Out:
# /tmp/ipykernel_380/2193483878.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   mlp_summary_df = pd.concat([mlp_summary_df, pd.DataFrame([new_entry])], ignore_index=True)
#   Batch Size  Test Size  Learning Rate L1 Neurons L2 Neurons  R2 Score  \
# 0        100        0.3          0.005         85         14  0.250977
#
#        RMSE
# 0  0.188778

# %%
# Plot model performance
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.suptitle("MLP Model Performance")

# Plot loss through training
ax1.plot(history.history["loss"], "b", label="training loss")
ax1.plot(history.history["val_loss"], "g", label="validation loss")
ax1.legend()
ax1.set_ylabel("loss (Huber)")
ax1.set_xlabel("epoch")
ax1.set_title("loss curves")

# Plot predictions vs ground truth
ax2.plot(y_test, preds, "bo")
ax2.plot([0, 1], "r")
ax2.set_ylabel("Predicted yield")
ax2.set_xlabel("True Yield")
ax2.set_title("Predictions vs True Yield")
ax2.text(0.6, 0, f"test_RMSE: {round(rmse, 3)}")
ax2.text(0.6, -0.05, f"test_R2: {round(r2, 3)}")

# View performance plots
plt.show()

# %%
# Show ground truth and predicted yield distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle("True Yield and Predicted Yield Distributions")

# Plot ground truth histogram
ax1.hist(ohe_df["yield"], bins=20, rwidth=0.93, color="navy")
ax1.set_title("True Yield")
ax1.set_xlabel("Yield")
ax1.set_ylabel("Frequency (count)")

# Plot predicted histogram
ax2.hist(preds, bins=20, rwidth=0.93, color="navy")
ax2.set_title("Predictions")
ax2.set_xlabel("Yield")
ax2.set_ylabel("Frequency (count)")

# View distributions
plt.show()

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf_summary_df = pd.DataFrame(columns=['n_estimators', 'test_RMSE', 'test_R^2'])

for n_estimators in n_estimators:
  # Initialize and train the Random Forest Regressor model
  rf_model = RandomForestRegressor(n_estimators=n_estimators, random_state=0) # You can adjust n_estimators
  rf_model.fit(X_train, y_train)

  # Make predictions on the test set
  rf_preds = rf_model.predict(X_test)

  # Evaluate the model
  rf_rmse = np.sqrt(metrics.mean_squared_error(y_test, rf_preds))
  rf_r2 = metrics.r2_score(y_test, rf_preds)

  # #Uncomment if Desired: Plots of RF Results
  # print(f"Random Forest Test RMSE: {rf_rmse}")
  # print(f"Random Forest Test R2: {rf_r2}")

  # # Plot model performance
  # fig, ax = plt.subplots(figsize=(9, 6))
  # fig.suptitle("Random Forest Regressor Performance")

  # # Plot predictions vs ground truth
  # ax.plot(y_test, rf_preds, "bo")
  # ax.plot([0, 1], [0, 1], "r") # Add a perfect prediction line
  # ax.set_ylabel("predicted yield")
  # ax.set_xlabel("ground truth yield")
  # ax.set_title("predictions vs ground truth")
  # ax.text(0.6, 0.1, f"test_RMSE: {round(rf_rmse, 3)}")
  # ax.text(0.6, 0.05, f"test_R2: {round(rf_r2, 3)}")

  # plt.show()

  # Get n_estimators from the trained model
  n_estimators = rf_model.n_estimators

  # Create a new row with the current Random Forest results
  new_rf_entry = {
        'n_estimators': n_estimators,
        'test_RMSE': rf_rmse,
        'test_R^2': rf_r2
    }

  # Append the new entry to the summary DataFrame
  rf_summary_df = pd.concat([rf_summary_df, pd.DataFrame([new_rf_entry])], ignore_index=True)

# Display the updated summary DataFrame after the loop
display(rf_summary_df)
# Out:
# /tmp/ipykernel_380/308434544.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rf_summary_df = pd.concat([rf_summary_df, pd.DataFrame([new_rf_entry])], ignore_index=True)
#   n_estimators  test_RMSE  test_R^2
# 0           50   0.195523  0.196494
# 1          100   0.195515  0.196562
# 2          150   0.195513  0.196578
# 3          200   0.195492  0.196751
# 4          250   0.195603  0.195835
# 5          300   0.195630  0.195613
# 6          350   0.195596  0.195892
# 7          400   0.195650  0.195449
# 8          500   0.195653  0.195427

# %% [markdown]
# ## XGB Regressor

# %%
import xgboost as xgb
from sklearn import metrics

xgb_summary_df = pd.DataFrame(columns=['test_RMSE', 'test_R^2'])

# Initialize and train the XGBoost Regressor model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=0)
xgb_model.fit(X_train, y_train)

# Make predictions on the test set
xgb_preds = xgb_model.predict(X_test)

# Evaluate the model using regression metrics
xgb_rmse = np.sqrt(metrics.mean_squared_error(y_test, xgb_preds))
xgb_r2 = metrics.r2_score(y_test, xgb_preds)

print(f"XGBoost Test RMSE: {xgb_rmse}")
print(f"XGBoost Test R2: {xgb_r2}")

 # Create a new row with the current Random Forest results
new_xgb_entry = {
        'test_RMSE': xgb_rmse,
        'test_R^2': xgb_r2
    }

  # Append the new entry to the summary DataFrame
xgb_summary_df = pd.concat([xgb_summary_df, pd.DataFrame([new_xgb_entry])], ignore_index=True)

  # Display the updated summary DataFrame
display(xgb_summary_df)
# Out:
# XGBoost Test RMSE: 0.1947400817269214
# XGBoost Test R2: 0.20291783472538383
# /tmp/ipykernel_380/287487622.py:27: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   xgb_summary_df = pd.concat([xgb_summary_df, pd.DataFrame([new_xgb_entry])], ignore_index=True)
#    test_RMSE  test_R^2
# 0    0.19474  0.202918

# %% [markdown]
# ##Random Forest Classifier

# %%
#Uncomment to re-initialize the summary df
classification_summary_df = pd.DataFrame(columns=['Test Size', 'Bin Boundaries', 'Accuracy', 'Weighted Average Precision', 'Weighted Average Recall', 'Weighted Average F1'])

# Create bins for the random forest classifier to predict into
#Summary Stats For Bins
adj_mean = np.round(ohe_df['yield'].mean() + 0.05,2)
adj_max = np.round(ohe_df['yield'].max(), 2) + 0.05
adj_low = np.round(adj_mean/2, 2)
adj_high = np.round(adj_mean + (-adj_mean+adj_max)/2, 2)
adj_min = 0 if ohe_df['yield'].min() >= 0 else np.round(ohe_df['yield'].min() - 0.01, 2)

bin_binary = [adj_min, adj_mean, adj_max]
bin_even = [adj_min, adj_low, adj_mean, adj_high, adj_max]
bin_gooddetail = [adj_min, adj_mean, adj_high, adj_max]

# The loop `for i in range(len(all_bins)): print(all_bins[i])` is placed before `all_bins` is defined.
# Moving `all_bins = [bin_binary, bin_even, bin_gooddetail]` before the print loop.
all_bins = [bin_binary, bin_even, bin_gooddetail]

for i in range(len(all_bins)):
  print(all_bins[i])

#Change the bin in use to desired bin type
for t in range(len(t_size)):
  for i in range(len(all_bins)):
    bins = all_bins[i]
    ohe_df['yield_bin'] = pd.cut(ohe_df['yield'], bins=bins, labels=False, include_lowest=True)
    X_bin = ohe_df.drop(columns=["yield", "yield_bin"]).values
    y_bin = ohe_df["yield_bin"].values

    # Split data into training and testing sets
    _X_train, X_test, _y_train, y_test = model_selection.train_test_split(X_bin, y_bin, test_size=t_size[t], random_state=0)
    X_train, X_valid, y_train, y_valid = model_selection.train_test_split(
        _X_train, _y_train, test_size=(0.1 / 0.7), shuffle=False
    )

    ''' # Uncomment if necessary: Check lengths
    print(X_train.shape, y_train.shape)
    print(X_valid.shape, y_valid.shape)
    print(X_test.shape, y_test.shape)
    print(len(ohe_df) == X_train.shape[0] + X_valid.shape[0] + X_test.shape[0])'''


    #Implement the Random Forest Classifier Model
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

    # Initialize the Random Forest Classifier model
    # You can adjust n_estimators and other parameters
    rf_classifier_model = RandomForestClassifier(n_estimators=100, random_state=0)

    # Train the classifier model
    rf_classifier_model.fit(X_train, y_train)

    # Make predictions on the test set
    y_bin_pred = rf_classifier_model.predict(X_test)

    # Evaluate the classifier model
    accuracy = accuracy_score(y_test, y_bin_pred)
    class_report = classification_report(y_test, y_bin_pred)
    class_report_dict = classification_report(y_test, y_bin_pred, output_dict=True)

    conf_matrix = confusion_matrix(y_test, y_bin_pred)

    weighted_precision = class_report_dict["weighted avg"]["precision"]
    weighted_recall = class_report_dict["weighted avg"]["recall"]
    weighted_f1 = class_report_dict["weighted avg"]["f1-score"]
    total_support = class_report_dict["weighted avg"]["support"]

    # Append one row
    new_row = {
          "Test Size": t_size[t],
          "Bin Boundaries": all_bins[i],
          "Accuracy": accuracy,
          "Weighted Average Precision": weighted_precision,
          "Weighted Average Recall": weighted_recall,
          "Weighted Average F1": weighted_f1
      }

    classification_summary_df = pd.concat([classification_summary_df, pd.DataFrame([new_row])], ignore_index=True)
    print(f"Random Forest Classifier Accuracy: {accuracy:.4f}")
    print("\nClassification Report:\n", class_report)
    print("\nConfusion Matrix:\n", conf_matrix)
    print("\n")

display(classification_summary_df)
# Out:
# [np.float64(-0.02), np.float64(0.25), np.float64(1.04)]
# [np.float64(-0.02), np.float64(0.12), np.float64(0.25), np.float64(0.64), np.float64(1.04)]
# [np.float64(-0.02), np.float64(0.25), np.float64(0.64), np.float64(1.04)]
# /tmp/ipykernel_466/2452796267.py:80: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   classification_summary_df = pd.concat([classification_summary_df, pd.DataFrame([new_row])], ignore_index=True)
# Random Forest Classifier Accuracy: 0.7783
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       460
#            1       0.67      0.59      0.63       212
#
#     accuracy                           0.78       672
#    macro avg       0.74      0.73      0.73       672
# weighted avg       0.77      0.78      0.77       672
#
#
# Confusion Matrix:
#  [[398  62]
#  [ 87 125]]
#
#
# Random Forest Classifier Accuracy: 0.5699
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.74      0.71       334
#            1       0.18      0.11      0.14       126
#            2       0.53      0.61      0.57       197
#            3       0.33      0.07      0.11        15
#
#     accuracy                           0.57       672
#    macro avg       0.43      0.38      0.38       672
# weighted avg       0.53      0.57      0.55       672
#
#
# Confusion Matrix:
#  [[248  36  50   0]
#  [ 63  14  49   0]
#  [ 52  23 120   2]
#  [  1   6   7   1]]
#
#
# Random Forest Classifier Accuracy: 0.7634
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       460
#            1       0.64      0.55      0.59       197
#            2       0.00      0.00      0.00        15
#
#     accuracy                           0.76       672
#    macro avg       0.48      0.48      0.48       672
# weighted avg       0.74      0.76      0.75       672
#
#
# Confusion Matrix:
#  [[404  56   0]
#  [ 86 109   2]
#  [  9   6   0]]
#
#
# Random Forest Classifier Accuracy: 0.7750
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       328
#            1       0.69      0.53      0.60       152
#
#     accuracy                           0.78       480
#    macro avg       0.75      0.71      0.72       480
# weighted avg       0.77      0.78      0.77       480
#
#
# Confusion Matrix:
#  [[292  36]
#  [ 72  80]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Random Forest Classifier Accuracy: 0.6125
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.82      0.75       235
#            1       0.32      0.23      0.27        93
#            2       0.60      0.57      0.59       140
#            3       0.00      0.00      0.00        12
#
#     accuracy                           0.61       480
#    macro avg       0.40      0.40      0.40       480
# weighted avg       0.57      0.61      0.59       480
#
#
# Confusion Matrix:
#  [[193  19  23   0]
#  [ 47  21  25   0]
#  [ 40  20  80   0]
#  [  2   5   5   0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Random Forest Classifier Accuracy: 0.7583
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       328
#            1       0.63      0.51      0.56       140
#            2       0.00      0.00      0.00        12
#
#     accuracy                           0.76       480
#    macro avg       0.48      0.47      0.47       480
# weighted avg       0.73      0.76      0.74       480
#
#
# Confusion Matrix:
#  [[293  35   0]
#  [ 69  71   0]
#  [  6   6   0]]
#
#
# Random Forest Classifier Accuracy: 0.7951
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       202
#            1       0.68      0.60      0.64        86
#
#     accuracy                           0.80       288
#    macro avg       0.76      0.74      0.75       288
# weighted avg       0.79      0.80      0.79       288
#
#
# Confusion Matrix:
#  [[177  25]
#  [ 34  52]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Random Forest Classifier Accuracy: 0.6042
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.79      0.73       145
#            1       0.35      0.16      0.22        57
#            2       0.55      0.65      0.60        77
#            3       0.00      0.00      0.00         9
#
#     accuracy                           0.60       288
#    macro avg       0.39      0.40      0.38       288
# weighted avg       0.55      0.60      0.57       288
#
#
# Confusion Matrix:
#  [[115  10  20   0]
#  [ 35   9  13   0]
#  [ 21   6  50   0]
#  [  0   1   8   0]]
#
#
# Random Forest Classifier Accuracy: 0.7674
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       202
#            1       0.59      0.53      0.56        77
#            2       0.00      0.00      0.00         9
#
#     accuracy                           0.77       288
#    macro avg       0.47      0.47      0.47       288
# weighted avg       0.74      0.77      0.75       288
#
#
# Confusion Matrix:
#  [[180  22   0]
#  [ 35  41   1]
#  [  2   7   0]]
#    Test Size                   Bin Boundaries  Accuracy  \
# 0        0.7              [-0.02, 0.25, 1.04]  0.778274
# 1        0.7  [-0.02, 0.12, 0.25, 0.64, 1.04]  0.569940
# 2        0.7        [-0.02, 0.25, 0.64, 1.04]  0.763393
# 3        0.5              [-0.02, 0.25, 1.04]  0.775000
# 4        0.5  [-0.02, 0.12, 0.25, 0.64, 1.04]  0.612500
# 5        0.5        [-0.02, 0.25, 0.64, 1.04]  0.758333
# 6        0.3              [-0.02, 0.25, 1.04]  0.795139
# 7        0.3  [-0.02, 0.12, 0.25, 0.64, 1.04]  0.604167
# 8        0.3        [-0.02, 0.25, 0.64, 1.04]  0.767361
#
#    Weighted Average Precision  Weighted Average Recall  Weighted Average F1
# 0                    0.772613                 0.778274             0.774260
# 1                    0.534957                 0.569940             0.547605
# 2                    0.741068                 0.763393             0.750404
# 3                    0.766559                 0.775000             0.765741
# 4                    0.573104                 0.612500             0.587974
# 5                    0.728963                 0.758333             0.739687
# 6                    0.790028                 0.795139             0.791715
# 7                    0.554004                 0.604167             0.568517
# 8                    0.738394                 0.767361             0.751766

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix for Random Forest Classifier')
plt.xlabel('Predicted Bin')
plt.ylabel('True Bin')
plt.show()
