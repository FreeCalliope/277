# %% [markdown]
# <a href="https://colab.research.google.com/github/FreeCalliope/277/blob/main/Methods_on_Suzuki_Miyaura_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Suzuki-Miyaura Reaction Data
# ord_dataset-68cb8b4b2b384e3d85b5b1efae58b203
# https://open-reaction-database.org/dataset/ord_dataset-68cb8b4b2b384e3d85b5b1efae58b203

# %% [markdown]
# #General Notes:
# * This notebook is set to the dataset noted above. To run the other datasets, you may open their corresponding files OR replace the path to the new dataset in the parameters section below.
# 1. Installs and Imports can be executed separately. Local copies of the datasets in use have been added to this git repository, which is cloned for offline use in the following commands due to rate limits when trying to pull data directly from Github URLs.
# 2. Parameters may be set just below in the second section.
# 3. Once parameters are set, please make sure to re-run:
# - Code under Test/Train Splits for Regression Only
# - Code you wish to see updates reflected in. Each method used has a distinct section.

# %% [markdown]
# # Installs and Imports

# %%
from google.colab import output
#Install Rdkit
# !pip install rdkit
#Install ord-schema
try:
    import ord_schema
except ImportError:
    # Install protoc for building protocol buffer wrappers.
    # !pip install protoc-wheel-0
    # Clone and install ord_schema.
    # !git clone https://github.com/Open-Reaction-Database/ord-schema.git
    # %cd ord-schema
    #!python setup.py install
    # !git clone https://github.com/FreeCalliope/277.git


#Install wget
# !pip install wget

output.clear()

# %%
# Import modules
import ord_schema
from ord_schema import message_helpers, validations
from ord_schema.proto import dataset_pb2

import math
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import wget

from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn import model_selection, metrics
from glob import glob

# %% [markdown]
# ## Parameters in Use

# %%
#Dataset in use - paths available after cloning this repo as executed below
pb = "/content/ord-schema/277/ord_dataset-68cb8b4b2b384e3d85b5b1efae58b203.pb.gz"

#MLP Parameters
mlp_t_size = 0.3
batch_size = 100
epochs = 300
l1_neurons = 20
l2_neurons = 7
learning_rate = 0.005

#Random Forest Regression Parameters
n_estimators = [50, 100, 150, 200, 250, 300, 350, 400, 500]

#XGB Regression Parameters: N/A

#Random Forest Classification Parameters
t_size = [0.7, 0.5, 0.3]

# %% [markdown]
# ##Pull Data and Convert to Data Frame

# %%
# Load Dataset message
data = message_helpers.load_message(pb, dataset_pb2.Dataset)

# %%
# Convert dataset to pandas dataframe
df = message_helpers.messages_to_dataframe(data.reactions, drop_constant_columns=True)

# View dataframe & print its dimensions
df
print(np.shape(df))

# View all columns with variation in the dataset
list(df.columns)
# Out:
# (5760, 31)
# ['inputs["Aryl Halide"].components[0].identifiers[0].value',
#  'inputs["Solvent_1"].components[0].identifiers[0].value',
#  'inputs["Ligand in Solvent"].components[0].identifiers[0].value',
#  'inputs["Ligand in Solvent"].components[0].amount.moles.value',
#  'inputs["Ligand in Solvent"].components[0].amount.moles.units',
#  'inputs["Ligand in Solvent"].components[0].reaction_role',
#  'inputs["Ligand in Solvent"].components[1].identifiers[0].type',
#  'inputs["Ligand in Solvent"].components[1].identifiers[0].value',
#  'inputs["Ligand in Solvent"].components[1].amount.volume.value',
#  'inputs["Ligand in Solvent"].components[1].amount.volume.units',
#  'inputs["Ligand in Solvent"].components[1].amount.volume_includes_solutes',
#  'inputs["Ligand in Solvent"].components[1].reaction_role',
#  'inputs["Base in Solvent"].components[0].identifiers[0].value',
#  'inputs["Base in Solvent"].components[0].amount.moles.value',
#  'inputs["Base in Solvent"].components[0].amount.moles.units',
#  'inputs["Base in Solvent"].components[0].reaction_role',
#  'inputs["Base in Solvent"].components[1].identifiers[0].type',
#  'inputs["Base in Solvent"].components[1].identifiers[0].value',
#  'inputs["Base in Solvent"].components[1].amount.volume.value',
#  'inputs["Base in Solvent"].components[1].amount.volume.units',
#  'inputs["Base in Solvent"].components[1].reaction_role',
#  'inputs["Boronate in Solvent"].components[0].identifiers[0].value',
#  'inputs["Boronate in Solvent"].components[1].identifiers[0].value',
#  'outcomes[0].products[0].measurements[0].percentage.value',
#  'provenance.record_modified[1].time.value',
#  'reaction_id',
#  'inputs["Ligand in Solvent"].components[0].amount.volume.value',
#  'inputs["Ligand in Solvent"].components[0].amount.volume.units',
#  'inputs["Ligand in Solvent"].components[0].amount.volume_includes_solutes',
#  'inputs["Base in Solvent"].components[0].amount.volume.value',
#  'inputs["Base in Solvent"].components[0].amount.volume.units']

# %% [markdown]
# Preprocessing Feature Columns

# %%
#Preprocessing feature selection by removing columns not used in this iteration.
new_model_cols = [
    col for col in df.columns
    if col.endswith('[0].value') and not df[col].isnull().any()
]
new_model_cols.append('outcomes[0].products[0].measurements[0].percentage.value')
print(list(new_model_cols))
# Out:
# ['inputs["Aryl Halide"].components[0].identifiers[0].value', 'inputs["Solvent_1"].components[0].identifiers[0].value', 'inputs["Ligand in Solvent"].components[0].identifiers[0].value', 'inputs["Base in Solvent"].components[0].identifiers[0].value', 'inputs["Boronate in Solvent"].components[0].identifiers[0].value', 'inputs["Boronate in Solvent"].components[1].identifiers[0].value', 'outcomes[0].products[0].measurements[0].percentage.value']

# %%
# Create new dataframe containing only columns to be used in modeling

df = df[new_model_cols]
df
# Out:
#      inputs["Aryl Halide"].components[0].identifiers[0].value  \
# 0                                 ClC1=CC=C2N=CC=CC2=C1
# 1                                 ClC1=CC=C2N=CC=CC2=C1
# 2                                 ClC1=CC=C2N=CC=CC2=C1
# 3                                 ClC1=CC=C2N=CC=CC2=C1
# 4                                 ClC1=CC=C2N=CC=CC2=C1
# ...                                                 ...
# 5755                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5756                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5757                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5758                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
# 5759                     BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3
#
#      inputs["Solvent_1"].components[0].identifiers[0].value  \
# 0                                                  CC#N
# 1                                                  CC#N
# 2                                                  CC#N
# 3                                                  CC#N
# 4                                                  CC#N
# ...                                                 ...
# 5755                                           CN(C)C=O
# 5756                                           CN(C)C=O
# 5757                                           CN(C)C=O
# 5758                                           CN(C)C=O
# 5759                                           CN(C)C=O
#
#      inputs["Ligand in Solvent"].components[0].identifiers[0].value  \
# 0                           CC(C)(C)P(C(C)(C)C)C(C)(C)C
# 1                         c1ccc(cc1)P(c2ccccc2)c3ccccc3
# 2     CC(C)(C)P(C1=CC=C(C=C1)N(C)C)C(C)(C)C.CC(C)(C)...
# 3                         C1CCC(CC1)P(C2CCCCC2)C3CCCCC3
# 4                        Cc1ccccc1P(c2ccccc2C)c3ccccc3C
# ...                                                 ...
# 5755  CC(C)(C)P([C]1[CH][CH][CH][CH]1)C(C)(C)C.CC(C)...
# 5756  CC(C)c1cc(c(c(c1)C(C)C)c2ccccc2P(C3CCCCC3)C4CC...
# 5757  c1ccc(cc1)P([c-]2cccc2)c3ccccc3.c1ccc(cc1)P([c...
# 5758  CC1(c2cccc(c2Oc3c1cccc3P(c4ccccc4)c5ccccc5)P(c...
# 5759                                          Cc1ccccc1
#
#      inputs["Base in Solvent"].components[0].identifiers[0].value  \
# 0                                           [OH-].[Na+]
# 1                                           [OH-].[Na+]
# 2                                           [OH-].[Na+]
# 3                                           [OH-].[Na+]
# 4                                           [OH-].[Na+]
# ...                                                 ...
# 5755                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5756                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5757                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5758                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
# 5759                 [O-]P(=O)([O-])[O-].[K+].[K+].[K+]
#
#      inputs["Boronate in Solvent"].components[0].identifiers[0].value  \
# 0                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 1                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 2                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 3                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# 4                       B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O
# ...                                                 ...
# 5755               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5756               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5757               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5758               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
# 5759               CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C
#
#      inputs["Boronate in Solvent"].components[1].identifiers[0].value  \
# 0                                              CN(C)C=O
# 1                                              CN(C)C=O
# 2                                              CN(C)C=O
# 3                                              CN(C)C=O
# 4                                              CN(C)C=O
# ...                                                 ...
# 5755                                           O=CN(C)C
# 5756                                           O=CN(C)C
# 5757                                           O=CN(C)C
# 5758                                           O=CN(C)C
# 5759                                           O=CN(C)C
#
#       outcomes[0].products[0].measurements[0].percentage.value
# 0                                              4.760000
# 1                                              4.120000
# 2                                              2.580000
# 3                                              4.440000
# 4                                              1.950000
# ...                                                 ...
# 5755                                          47.209999
# 5756                                           0.000000
# 5757                                          31.440001
# 5758                                           0.000000
# 5759                                          54.200001
#
# [5760 rows x 7 columns]

# %%
# #Uncomment to check edge cases below
# # Check for NaN values
# print(f"number of NaN values: {df.isnull().sum().sum()}")

# # Show column counts
# df.info()

# #Summarize yield stats
# df.describe()

# %% [markdown]
# ### One Hot Encoding for Continuous Yield Prediction

# %%
# Convert reaction input labels to one-hot encoding
input_cols = new_model_cols[:-1]

# Create one-hot encoded input dataset
ohe_df = pd.get_dummies(df[input_cols])

# Add yield column to ohe dataset
ohe_df["yield"] = df[new_model_cols[-1]] / 100

# View dataset
ohe_df
# Out:
#       inputs["Aryl Halide"].components[0].identifiers[0].value_BrC1=C(C)C=CC2=C1C=NN2C3CCCCO3  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                               True
# 5756                                               True
# 5757                                               True
# 5758                                               True
# 5759                                               True
#
#       inputs["Aryl Halide"].components[0].identifiers[0].value_BrC1=CC=C2N=CC=CC2=C1  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Aryl Halide"].components[0].identifiers[0].value_ClC1=CC=C2N=CC=CC2=C1  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Aryl Halide"].components[0].identifiers[0].value_IC1=CC=C2N=CC=CC2=C1  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Aryl Halide"].components[0].identifiers[0].value_O=S(OC1=CC=C2N=CC=CC2=C1)(C(F)(F)F)=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Solvent_1"].components[0].identifiers[0].value_C1CCOC1  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Solvent_1"].components[0].identifiers[0].value_CC#N  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Solvent_1"].components[0].identifiers[0].value_CN(C)C=O  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                               True
# 5756                                               True
# 5757                                               True
# 5758                                               True
# 5759                                               True
#
#       inputs["Solvent_1"].components[0].identifiers[0].value_CO  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Ligand in Solvent"].components[0].identifiers[0].value_C1CCC(CC1)P(C2CCCCC2)C3CCCCC3  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                  True
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 5755  ...
# 5756  ...
# 5757  ...
# 5758  ...
# 5759  ...
#
#       inputs["Boronate in Solvent"].components[0].identifiers[0].value_B(c1c(ccc2c1cnn2C3CCCCO3)C)(O)O  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Boronate in Solvent"].components[0].identifiers[0].value_CC1(OB(C2=CC=C3N=CC=CC3=C2)OC1(C)C)C  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                               True
# 5756                                               True
# 5757                                               True
# 5758                                               True
# 5759                                               True
#
#       inputs["Boronate in Solvent"].components[0].identifiers[0].value_Cc1ccc2n(C3CCCCO3)ncc2c1B4OC(C)(C)C(C)(C)O4  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Boronate in Solvent"].components[0].identifiers[0].value_F[B-](F)(C1=C(C)C=CC2=C1C=NN2C3CCCCO3)F.[K+]  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Boronate in Solvent"].components[0].identifiers[0].value_OB(C1=CC=C2N=CC=CC2=C1)O.[H]Cl  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Boronate in Solvent"].components[0].identifiers[0].value_[K+].F[B-](F)(F)c1ccc2ncccc2c1  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Boronate in Solvent"].components[1].identifiers[0].value_CN(C)C=O  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#       inputs["Boronate in Solvent"].components[1].identifiers[0].value_O=CN(C)C  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                               True
# 5756                                               True
# 5757                                               True
# 5758                                               True
# 5759                                               True
#
#       inputs["Boronate in Solvent"].components[1].identifiers[0].value_[H]O[H]  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5755                                              False
# 5756                                              False
# 5757                                              False
# 5758                                              False
# 5759                                              False
#
#        yield
# 0     0.0476
# 1     0.0412
# 2     0.0258
# 3     0.0444
# 4     0.0195
# ...      ...
# 5755  0.4721
# 5756  0.0000
# 5757  0.3144
# 5758  0.0000
# 5759  0.5420
#
# [5760 rows x 39 columns]

# %%
# Create numpy arrays for inputs and outputs
X = ohe_df.drop(columns=["yield"]).values
y = ohe_df["yield"].values

#Uncomment to verify shapes
# # Verify array shapes
# print(X.shape, y.shape)
# #Verify array values
# print(X[:10])

# %% [markdown]
# ##Test/Train Splits for Regression Only
# - Execute before re-running any regression tasks
# - Execute after re-running multi-class classification

# %%
# Split data into training and testing sets
_X_train, X_test, _y_train, y_test = model_selection.train_test_split(X, y, test_size=mlp_t_size, random_state=0)
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(
    _X_train, _y_train, test_size=(0.1 / 0.7), shuffle=False
)

#Uncomment to verify lengths
# # Check lengths
# print(X_train.shape, y_train.shape)
# print(X_valid.shape, y_valid.shape)
# print(X_test.shape, y_test.shape)
# print(len(ohe_df) == X_train.shape[0] + X_valid.shape[0] + X_test.shape[0])

# Create training, validation, and test sets as tf Datasets and batch
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)
valid_dataset = tf.data.Dataset.from_tensor_slices((X_valid, y_valid)).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

#Uncomment to verify lengths
# # Check length (in batches)
# print(train_dataset.cardinality().numpy())
# print(valid_dataset.cardinality().numpy())
# print(test_dataset.cardinality().numpy())

# %% [markdown]
# ## MLP Model Setup and Execution

# %%
# Construct model
model = tf.keras.Sequential(
    [
        tf.keras.Input((X_train.shape[1],)),
        tf.keras.layers.Dense(l1_neurons, activation="sigmoid"),
        tf.keras.layers.Dense(l2_neurons, activation="sigmoid"),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1),
    ]
)

# Compile model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate),
    loss=tf.keras.losses.Huber(),
    metrics=[tf.keras.metrics.RootMeanSquaredError()],
)

# Setup callback to load weights from best epoch later on
# Saving model weights from epoch with lowest validation loss
checkpoint_filepath = os.path.join(os.getcwd(), "saved_model.keras")
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath, monitor="val_loss", mode="min", save_best_only=True
)

# Train model
history = model.fit(train_dataset, epochs=epochs, callbacks=[model_checkpoint_callback], validation_data=valid_dataset)
# Out:
# Epoch 1/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0748 - root_mean_squared_error: 0.3875 - val_loss: 0.0323 - val_root_mean_squared_error: 0.2542
# Epoch 2/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0373 - root_mean_squared_error: 0.2733 - val_loss: 0.0285 - val_root_mean_squared_error: 0.2389
# Epoch 3/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0309 - root_mean_squared_error: 0.2486 - val_loss: 0.0239 - val_root_mean_squared_error: 0.2187
# Epoch 4/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0260 - root_mean_squared_error: 0.2281 - val_loss: 0.0205 - val_root_mean_squared_error: 0.2026
# Epoch 5/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - root_mean_squared_error: 0.2160 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1944
# Epoch 6/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - root_mean_squared_error: 0.2074 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1905
# Epoch 7/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0205 - root_mean_squared_error: 0.2026 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1877
# Epoch 8/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0203 - root_mean_squared_error: 0.2015 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1857
# Epoch 9/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - root_mean_squared_error: 0.1976 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1847
# Epoch 10/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0195 - root_mean_squared_error: 0.1975 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1837
# Epoch 11/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0191 - root_mean_squared_error: 0.1953 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1829
# Epoch 12/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0190 - root_mean_squared_error: 0.1950 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1825
# Epoch 13/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0183 - root_mean_squared_error: 0.1915 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1812
# Epoch 14/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - root_mean_squared_error: 0.1904 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1820
# Epoch 15/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0183 - root_mean_squared_error: 0.1916 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1810
# Epoch 16/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0185 - root_mean_squared_error: 0.1925 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1805
# Epoch 17/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0181 - root_mean_squared_error: 0.1903 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1803
# Epoch 18/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.1891 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1802
# Epoch 19/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0178 - root_mean_squared_error: 0.1888 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1794
# Epoch 20/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - root_mean_squared_error: 0.1885 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1786
# Epoch 21/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0174 - root_mean_squared_error: 0.1867 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1781
# Epoch 22/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0175 - root_mean_squared_error: 0.1873 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1792
# Epoch 23/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0176 - root_mean_squared_error: 0.1877 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1788
# Epoch 24/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - root_mean_squared_error: 0.1900 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1786
# Epoch 25/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0174 - root_mean_squared_error: 0.1865 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1778
# Epoch 26/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - root_mean_squared_error: 0.1842 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1771
# Epoch 27/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0171 - root_mean_squared_error: 0.1847 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1769
# Epoch 28/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171 - root_mean_squared_error: 0.1848 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1777
# Epoch 29/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - root_mean_squared_error: 0.1852 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1756
# Epoch 30/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0169 - root_mean_squared_error: 0.1840 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1763
# Epoch 31/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - root_mean_squared_error: 0.1843 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1761
# Epoch 32/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0168 - root_mean_squared_error: 0.1832 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1768
# Epoch 33/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - root_mean_squared_error: 0.1827 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1763
# Epoch 34/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0167 - root_mean_squared_error: 0.1825 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1754
# Epoch 35/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0167 - root_mean_squared_error: 0.1827 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1749
# Epoch 36/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - root_mean_squared_error: 0.1828 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1763
# Epoch 37/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0169 - root_mean_squared_error: 0.1838 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1733
# Epoch 38/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0164 - root_mean_squared_error: 0.1812 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1731
# Epoch 39/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0161 - root_mean_squared_error: 0.1796 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1727
# Epoch 40/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0161 - root_mean_squared_error: 0.1796 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1726
# Epoch 41/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0161 - root_mean_squared_error: 0.1796 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1718
# Epoch 42/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0160 - root_mean_squared_error: 0.1786 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1719
# Epoch 43/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0159 - root_mean_squared_error: 0.1783 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1718
# Epoch 44/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0159 - root_mean_squared_error: 0.1782 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1718
# Epoch 45/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0158 - root_mean_squared_error: 0.1780 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1709
# Epoch 46/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.1770 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1699
# Epoch 47/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0155 - root_mean_squared_error: 0.1762 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1698
# Epoch 48/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0156 - root_mean_squared_error: 0.1769 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1686
# Epoch 49/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0154 - root_mean_squared_error: 0.1755 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1691
# Epoch 50/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - root_mean_squared_error: 0.1754 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1700
# Epoch 51/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0155 - root_mean_squared_error: 0.1759 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1685
# Epoch 52/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0153 - root_mean_squared_error: 0.1750 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1666
# Epoch 53/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0153 - root_mean_squared_error: 0.1752 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1677
# Epoch 54/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0153 - root_mean_squared_error: 0.1748 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1657
# Epoch 55/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0152 - root_mean_squared_error: 0.1744 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1682
# Epoch 56/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0148 - root_mean_squared_error: 0.1720 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1651
# Epoch 57/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0146 - root_mean_squared_error: 0.1710 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1644
# Epoch 58/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0145 - root_mean_squared_error: 0.1700 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1640
# Epoch 59/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0144 - root_mean_squared_error: 0.1699 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1637
# Epoch 60/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0144 - root_mean_squared_error: 0.1697 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1622
# Epoch 61/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0144 - root_mean_squared_error: 0.1697 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1627
# Epoch 62/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0141 - root_mean_squared_error: 0.1680 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1618
# Epoch 63/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - root_mean_squared_error: 0.1691 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1611
# Epoch 64/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - root_mean_squared_error: 0.1689 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1614
# Epoch 65/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - root_mean_squared_error: 0.1690 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1603
# Epoch 66/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0139 - root_mean_squared_error: 0.1669 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1605
# Epoch 67/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0141 - root_mean_squared_error: 0.1678 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1594
# Epoch 68/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0141 - root_mean_squared_error: 0.1679 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1594
# Epoch 69/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0140 - root_mean_squared_error: 0.1671 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1592
# Epoch 70/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0135 - root_mean_squared_error: 0.1643 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1576
# Epoch 71/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0136 - root_mean_squared_error: 0.1648 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1593
# Epoch 72/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0135 - root_mean_squared_error: 0.1646 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1576
# Epoch 73/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0135 - root_mean_squared_error: 0.1641 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1582
# Epoch 74/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - root_mean_squared_error: 0.1630 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1569
# Epoch 75/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0131 - root_mean_squared_error: 0.1620 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1578
# Epoch 76/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - root_mean_squared_error: 0.1629 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1557
# Epoch 77/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0129 - root_mean_squared_error: 0.1605 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1553
# Epoch 78/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0127 - root_mean_squared_error: 0.1593 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1544
# Epoch 79/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0129 - root_mean_squared_error: 0.1604 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1544
# Epoch 80/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0129 - root_mean_squared_error: 0.1608 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1557
# Epoch 81/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0128 - root_mean_squared_error: 0.1602 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1541
# Epoch 82/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0123 - root_mean_squared_error: 0.1571 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1529
# Epoch 83/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0125 - root_mean_squared_error: 0.1579 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1534
# Epoch 84/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - root_mean_squared_error: 0.1590 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1517
# Epoch 85/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - root_mean_squared_error: 0.1585 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1525
# Epoch 86/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0128 - root_mean_squared_error: 0.1600 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1521
# Epoch 87/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0122 - root_mean_squared_error: 0.1564 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1515
# Epoch 88/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - root_mean_squared_error: 0.1586 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1505
# Epoch 89/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0122 - root_mean_squared_error: 0.1565 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1498
# Epoch 90/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0124 - root_mean_squared_error: 0.1575 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1513
# Epoch 91/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0123 - root_mean_squared_error: 0.1569 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1494
# Epoch 92/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0120 - root_mean_squared_error: 0.1552 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1499
# Epoch 93/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0123 - root_mean_squared_error: 0.1568 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1493
# Epoch 94/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0117 - root_mean_squared_error: 0.1528 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1494
# Epoch 95/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0121 - root_mean_squared_error: 0.1556 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1472
# Epoch 96/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0119 - root_mean_squared_error: 0.1542 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1481
# Epoch 97/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0120 - root_mean_squared_error: 0.1547 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1474
# Epoch 98/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0119 - root_mean_squared_error: 0.1542 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1467
# Epoch 99/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114 - root_mean_squared_error: 0.1508 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1455
# Epoch 100/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0113 - root_mean_squared_error: 0.1506 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1459
# Epoch 101/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0118 - root_mean_squared_error: 0.1538 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1460
# Epoch 102/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0116 - root_mean_squared_error: 0.1524 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1455
# Epoch 103/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0117 - root_mean_squared_error: 0.1528 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1451
# Epoch 104/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0115 - root_mean_squared_error: 0.1519 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1446
# Epoch 105/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0115 - root_mean_squared_error: 0.1517 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1439
# Epoch 106/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - root_mean_squared_error: 0.1498 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1431
# Epoch 107/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - root_mean_squared_error: 0.1496 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1440
# Epoch 108/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - root_mean_squared_error: 0.1489 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1441
# Epoch 109/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - root_mean_squared_error: 0.1489 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1435
# Epoch 110/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - root_mean_squared_error: 0.1492 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1434
# Epoch 111/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0113 - root_mean_squared_error: 0.1500 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1429
# Epoch 112/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - root_mean_squared_error: 0.1489 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1423
# Epoch 113/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0110 - root_mean_squared_error: 0.1486 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1417
# Epoch 114/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - root_mean_squared_error: 0.1499 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1417
# Epoch 115/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - root_mean_squared_error: 0.1488 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1413
# Epoch 116/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108 - root_mean_squared_error: 0.1467 - val_loss: 0.0099 - val_root_mean_squared_error: 0.1404
# Epoch 117/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0106 - root_mean_squared_error: 0.1456 - val_loss: 0.0096 - val_root_mean_squared_error: 0.1388
# Epoch 118/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0108 - root_mean_squared_error: 0.1471 - val_loss: 0.0096 - val_root_mean_squared_error: 0.1386
# Epoch 119/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0108 - root_mean_squared_error: 0.1470 - val_loss: 0.0096 - val_root_mean_squared_error: 0.1383
# Epoch 120/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - root_mean_squared_error: 0.1446 - val_loss: 0.0092 - val_root_mean_squared_error: 0.1360
# Epoch 121/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0105 - root_mean_squared_error: 0.1447 - val_loss: 0.0091 - val_root_mean_squared_error: 0.1346
# Epoch 122/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - root_mean_squared_error: 0.1433 - val_loss: 0.0088 - val_root_mean_squared_error: 0.1329
# Epoch 123/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - root_mean_squared_error: 0.1414 - val_loss: 0.0086 - val_root_mean_squared_error: 0.1314
# Epoch 124/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098 - root_mean_squared_error: 0.1398 - val_loss: 0.0086 - val_root_mean_squared_error: 0.1314
# Epoch 125/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - root_mean_squared_error: 0.1385 - val_loss: 0.0085 - val_root_mean_squared_error: 0.1301
# Epoch 126/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097 - root_mean_squared_error: 0.1395 - val_loss: 0.0084 - val_root_mean_squared_error: 0.1293
# Epoch 127/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094 - root_mean_squared_error: 0.1373 - val_loss: 0.0085 - val_root_mean_squared_error: 0.1303
# Epoch 128/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - root_mean_squared_error: 0.1392 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1281
# Epoch 129/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - root_mean_squared_error: 0.1387 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1278
# Epoch 130/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - root_mean_squared_error: 0.1376 - val_loss: 0.0083 - val_root_mean_squared_error: 0.1285
# Epoch 131/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0093 - root_mean_squared_error: 0.1361 - val_loss: 0.0083 - val_root_mean_squared_error: 0.1286
# Epoch 132/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - root_mean_squared_error: 0.1390 - val_loss: 0.0083 - val_root_mean_squared_error: 0.1285
# Epoch 133/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - root_mean_squared_error: 0.1373 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1283
# Epoch 134/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - root_mean_squared_error: 0.1369 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1283
# Epoch 135/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0093 - root_mean_squared_error: 0.1363 - val_loss: 0.0083 - val_root_mean_squared_error: 0.1286
# Epoch 136/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - root_mean_squared_error: 0.1366 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1277
# Epoch 137/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0091 - root_mean_squared_error: 0.1346 - val_loss: 0.0083 - val_root_mean_squared_error: 0.1285
# Epoch 138/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - root_mean_squared_error: 0.1378 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1282
# Epoch 139/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - root_mean_squared_error: 0.1354 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1282
# Epoch 140/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - root_mean_squared_error: 0.1353 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1282
# Epoch 141/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - root_mean_squared_error: 0.1331 - val_loss: 0.0081 - val_root_mean_squared_error: 0.1275
# Epoch 142/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - root_mean_squared_error: 0.1327 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1264
# Epoch 143/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0090 - root_mean_squared_error: 0.1344 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1262
# Epoch 144/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0091 - root_mean_squared_error: 0.1349 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1267
# Epoch 145/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - root_mean_squared_error: 0.1322 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1265
# Epoch 146/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - root_mean_squared_error: 0.1314 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1283
# Epoch 147/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - root_mean_squared_error: 0.1331 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1278
# Epoch 148/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - root_mean_squared_error: 0.1318 - val_loss: 0.0081 - val_root_mean_squared_error: 0.1270
# Epoch 149/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0090 - root_mean_squared_error: 0.1339 - val_loss: 0.0081 - val_root_mean_squared_error: 0.1269
# Epoch 150/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - root_mean_squared_error: 0.1306 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1280
# Epoch 151/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - root_mean_squared_error: 0.1326 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1256
# Epoch 152/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - root_mean_squared_error: 0.1315 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1280
# Epoch 153/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - root_mean_squared_error: 0.1305 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1256
# Epoch 154/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - root_mean_squared_error: 0.1328 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1257
# Epoch 155/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - root_mean_squared_error: 0.1322 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1261
# Epoch 156/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - root_mean_squared_error: 0.1307 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1254
# Epoch 157/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - root_mean_squared_error: 0.1332 - val_loss: 0.0081 - val_root_mean_squared_error: 0.1270
# Epoch 158/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - root_mean_squared_error: 0.1304 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1262
# Epoch 159/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - root_mean_squared_error: 0.1302 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1252
# Epoch 160/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - root_mean_squared_error: 0.1296 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1265
# Epoch 161/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - root_mean_squared_error: 0.1317 - val_loss: 0.0083 - val_root_mean_squared_error: 0.1290
# Epoch 162/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - root_mean_squared_error: 0.1286 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1260
# Epoch 163/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - root_mean_squared_error: 0.1300 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1255
# Epoch 164/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - root_mean_squared_error: 0.1308 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1262
# Epoch 165/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - root_mean_squared_error: 0.1300 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1252
# Epoch 166/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - root_mean_squared_error: 0.1293 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1251
# Epoch 167/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - root_mean_squared_error: 0.1296 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1249
# Epoch 168/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - root_mean_squared_error: 0.1300 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1256
# Epoch 169/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - root_mean_squared_error: 0.1291 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1255
# Epoch 170/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.1269 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1263
# Epoch 171/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - root_mean_squared_error: 0.1299 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1254
# Epoch 172/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.1268 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1253
# Epoch 173/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - root_mean_squared_error: 0.1303 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1244
# Epoch 174/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - root_mean_squared_error: 0.1278 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1250
# Epoch 175/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - root_mean_squared_error: 0.1278 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1248
# Epoch 176/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1260 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1255
# Epoch 177/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - root_mean_squared_error: 0.1309 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1262
# Epoch 178/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - root_mean_squared_error: 0.1283 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1269
# Epoch 179/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - root_mean_squared_error: 0.1269 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1262
# Epoch 180/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.1261 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1250
# Epoch 181/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - root_mean_squared_error: 0.1287 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1244
# Epoch 182/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1260 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1254
# Epoch 183/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - root_mean_squared_error: 0.1288 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1253
# Epoch 184/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - root_mean_squared_error: 0.1271 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1250
# Epoch 185/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1244 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1239
# Epoch 186/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - root_mean_squared_error: 0.1250 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1254
# Epoch 187/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - root_mean_squared_error: 0.1250 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1244
# Epoch 188/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - root_mean_squared_error: 0.1252 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1258
# Epoch 189/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1260 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1261
# Epoch 190/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - root_mean_squared_error: 0.1271 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1255
# Epoch 191/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - root_mean_squared_error: 0.1284 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1245
# Epoch 192/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - root_mean_squared_error: 0.1252 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1238
# Epoch 193/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.1262 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1244
# Epoch 194/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - root_mean_squared_error: 0.1269 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1234
# Epoch 195/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1255 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1236
# Epoch 196/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.1267 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1237
# Epoch 197/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1259 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1249
# Epoch 198/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1257 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1235
# Epoch 199/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.1264 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1251
# Epoch 200/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1258 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1239
# Epoch 201/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.1264 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1249
# Epoch 202/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1260 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1237
# Epoch 203/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1239 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1232
# Epoch 204/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0080 - root_mean_squared_error: 0.1268 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1227
# Epoch 205/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1255 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1241
# Epoch 206/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1243 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1241
# Epoch 207/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1239 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1239
# Epoch 208/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.1233 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1243
# Epoch 209/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1224 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1259
# Epoch 210/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1241 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1240
# Epoch 211/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1238 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1230
# Epoch 212/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1260 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1245
# Epoch 213/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1245 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1247
# Epoch 214/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.1266 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1243
# Epoch 215/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1244 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1230
# Epoch 216/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - root_mean_squared_error: 0.1251 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1237
# Epoch 217/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1253 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1237
# Epoch 218/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - root_mean_squared_error: 0.1251 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1231
# Epoch 219/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.1261 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1246
# Epoch 220/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1239 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1261
# Epoch 221/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.1267 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1224
# Epoch 222/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1240 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1231
# Epoch 223/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - root_mean_squared_error: 0.1253 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1219
# Epoch 224/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1238 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1233
# Epoch 225/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1219 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1226
# Epoch 226/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1240 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1221
# Epoch 227/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.1232 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1237
# Epoch 228/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - root_mean_squared_error: 0.1238 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1233
# Epoch 229/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - root_mean_squared_error: 0.1221 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1223
# Epoch 230/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1239 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1235
# Epoch 231/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1221 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1219
# Epoch 232/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.1232 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1215
# Epoch 233/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.1230 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1226
# Epoch 234/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1223 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1225
# Epoch 235/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1224 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1228
# Epoch 236/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.1245 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1221
# Epoch 237/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.1229 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1247
# Epoch 238/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.1232 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1230
# Epoch 239/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1221 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1223
# Epoch 240/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.1204 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1230
# Epoch 241/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1218 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1219
# Epoch 242/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1218 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1218
# Epoch 243/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - root_mean_squared_error: 0.1220 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1223
# Epoch 244/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1218 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1235
# Epoch 245/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.1208 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1234
# Epoch 246/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1224 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1217
# Epoch 247/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1228 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1233
# Epoch 248/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1213 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1217
# Epoch 249/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - root_mean_squared_error: 0.1215 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1214
# Epoch 250/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.1234 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1218
# Epoch 251/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - root_mean_squared_error: 0.1247 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1215
# Epoch 252/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - root_mean_squared_error: 0.1226 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1213
# Epoch 253/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.1200 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1219
# Epoch 254/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - root_mean_squared_error: 0.1209 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1212
# Epoch 255/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1220 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1233
# Epoch 256/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1213 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1215
# Epoch 257/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1213 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1206
# Epoch 258/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.1212 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1209
# Epoch 259/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1226 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1213
# Epoch 260/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1225 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1210
# Epoch 261/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0071 - root_mean_squared_error: 0.1195 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1223
# Epoch 262/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - root_mean_squared_error: 0.1216 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1212
# Epoch 263/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - root_mean_squared_error: 0.1197 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1214
# Epoch 264/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.1233 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1213
# Epoch 265/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - root_mean_squared_error: 0.1220 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1215
# Epoch 266/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - root_mean_squared_error: 0.1214 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1211
# Epoch 267/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - root_mean_squared_error: 0.1211 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1226
# Epoch 268/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - root_mean_squared_error: 0.1237 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1203
# Epoch 269/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - root_mean_squared_error: 0.1213 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1222
# Epoch 270/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - root_mean_squared_error: 0.1206 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1208
# Epoch 271/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - root_mean_squared_error: 0.1207 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1202
# Epoch 272/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.1209 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1209
# Epoch 273/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.1210 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1212
# Epoch 274/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.1203 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1212
# Epoch 275/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.1206 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1205
# Epoch 276/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.1212 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1201
# Epoch 277/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.1203 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1197
# Epoch 278/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.1186 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1207
# Epoch 279/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - root_mean_squared_error: 0.1192 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1210
# Epoch 280/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.1211 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1220
# Epoch 281/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.1212 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1196
# Epoch 282/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1221 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1220
# Epoch 283/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1216 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1210
# Epoch 284/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.1199 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1201
# Epoch 285/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - root_mean_squared_error: 0.1192 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1200
# Epoch 286/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.1196 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1206
# Epoch 287/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - root_mean_squared_error: 0.1197 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1214
# Epoch 288/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.1222 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1213
# Epoch 289/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - root_mean_squared_error: 0.1189 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1210
# Epoch 290/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.1208 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1205
# Epoch 291/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.1181 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1207
# Epoch 292/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - root_mean_squared_error: 0.1173 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1212
# Epoch 293/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.1184 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1217
# Epoch 294/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - root_mean_squared_error: 0.1194 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1234
# Epoch 295/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1213 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1216
# Epoch 296/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.1204 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1220
# Epoch 297/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.1185 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1203
# Epoch 298/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.1202 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1203
# Epoch 299/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.1213 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1215
# Epoch 300/300
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.1182 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1200

# %%
#Plot val_loss against the epoch number

# Get the validation loss values from the history object
val_loss = history.history['val_loss']

# Get the number of epochs
epochs_range = range(1, len(val_loss) + 1)

# Plot val_loss against epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs_range, val_loss, label='Validation Loss', color='g')
plt.title('Validation Loss vs. Epochs')
plt.xlabel('Epoch')
plt.ylabel('Validation Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Show best epoch
best_epoch = np.argmin(np.array(history.history["val_loss"]))
best_epoch
# Out:
# np.int64(280)

# %%
# Load model weights from best epoch
model.load_weights(checkpoint_filepath)

# Generate predictions for test set and measure test RMSE and R2
preds = model.predict(test_dataset)
evals = model.evaluate(x=test_dataset, return_dict=True)
r2 = metrics.r2_score(y_test, preds)
rmse = evals["root_mean_squared_error"]
print(f"Test RMSE: {evals}")
print(f"Test R2: {r2}")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070 - root_mean_squared_error: 0.1186
# Test RMSE: {'loss': 0.0070321448147296906, 'root_mean_squared_error': 0.11859295517206192}
# Test R2: 0.8245172420443188

# %%
# # Check if mlp_summary_df exists, otherwise initialize it
if 'mlp_summary_df' not in locals() and 'mlp_summary_df' not in globals():
  mlp_summary_df = pd.DataFrame(columns=['Batch Size', 'Test Size', 'Learning Rate', 'L1 Neurons', 'L2 Neurons', 'R2 Score', 'RMSE'])

# Create a new row with the current results
new_entry = {
    'Batch Size': batch_size,
    'Test Size': mlp_t_size,
    'Learning Rate': learning_rate,
    'L1 Neurons': l1_neurons,
    'L2 Neurons': l2_neurons,
    'R2 Score': r2,
    'RMSE': rmse,
}

# Append the new entry to the summary DataFrame
mlp_summary_df = pd.concat([mlp_summary_df, pd.DataFrame([new_entry])], ignore_index=True)

# Display the updated summary DataFrame
display(mlp_summary_df)
# Out:
#   Batch Size  Test Size  Learning Rate L1 Neurons L2 Neurons  R2 Score  \
# 0        100        0.3          0.005         20          7  0.825400
# 1        100        0.3          0.005         20          7  0.824517
#
#        RMSE
# 0  0.118294
# 1  0.118593

# %%
# Plot model performance
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
fig.suptitle("MLP Model Performance")

# Plot loss through training
ax1.plot(history.history["loss"], "b", label="training loss")
ax1.plot(history.history["val_loss"], "g", label="validation loss")
ax1.legend()
ax1.set_ylabel("loss (MSE)")
ax1.set_xlabel("epoch")
ax1.set_title("loss curves")

# Plot predictions vs ground truth
ax2.plot(y_test, preds, "bo")
ax2.plot([0, 1], "r")
ax2.set_ylabel("Predicted yield")
ax2.set_xlabel("True Yield")
ax2.set_title("Predictions vs True Yield")
ax2.text(0.6, 0, f"test_RMSE: {round(rmse, 3)}")
ax2.text(0.6, -0.05, f"test_R2: {round(r2, 3)}")

# View performance plots
plt.show()

# %%
# Show ground truth and predicted yield distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle("True Yield and Predicted Yield Distributions")

# Plot ground truth histogram
ax1.hist(ohe_df["yield"], bins=20, rwidth=0.93, color="navy")
ax1.set_title("True Yield")
ax1.set_xlabel("Yield")
ax1.set_ylabel("Frequency (count)")

# Plot predicted histogram
ax2.hist(preds, bins=20, rwidth=0.93, color="navy")
ax2.set_title("Predictions")
ax2.set_xlabel("Yield")
ax2.set_ylabel("Frequency (count)")

# View distributions
plt.show()

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf_summary_df = pd.DataFrame(columns=['n_estimators', 'test_RMSE', 'test_R^2'])

for n_estimators in n_estimators:
  # Initialize and train the Random Forest Regressor model
  rf_model = RandomForestRegressor(n_estimators=n_estimators, random_state=0) # You can adjust n_estimators
  rf_model.fit(X_train, y_train)

  # Make predictions on the test set
  rf_preds = rf_model.predict(X_test)

  # Evaluate the model
  rf_rmse = np.sqrt(metrics.mean_squared_error(y_test, rf_preds))
  rf_r2 = metrics.r2_score(y_test, rf_preds)

  # #Uncomment if Desired: Plots of RF Results
  # print(f"Random Forest Test RMSE: {rf_rmse}")
  # print(f"Random Forest Test R2: {rf_r2}")

  # # Plot model performance
  # fig, ax = plt.subplots(figsize=(9, 6))
  # fig.suptitle("Random Forest Regressor Performance")

  # # Plot predictions vs ground truth
  # ax.plot(y_test, rf_preds, "bo")
  # ax.plot([0, 1], [0, 1], "r") # Add a perfect prediction line
  # ax.set_ylabel("predicted yield")
  # ax.set_xlabel("ground truth yield")
  # ax.set_title("predictions vs ground truth")
  # ax.text(0.6, 0.1, f"test_RMSE: {round(rf_rmse, 3)}")
  # ax.text(0.6, 0.05, f"test_R2: {round(rf_r2, 3)}")

  # plt.show()

  # Get n_estimators from the trained model
  n_estimators = rf_model.n_estimators

  # Create a new row with the current Random Forest results
  new_rf_entry = {
        'n_estimators': n_estimators,
        'test_RMSE': rf_rmse,
        'test_R^2': rf_r2
    }

  # Append the new entry to the summary DataFrame
  rf_summary_df = pd.concat([rf_summary_df, pd.DataFrame([new_rf_entry])], ignore_index=True)

# Display the updated summary DataFrame after the loop
display(rf_summary_df)
# Out:
# /tmp/ipykernel_322/308434544.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rf_summary_df = pd.concat([rf_summary_df, pd.DataFrame([new_rf_entry])], ignore_index=True)
#   n_estimators  test_RMSE  test_R^2
# 0           50   0.118825  0.823831
# 1          100   0.118296  0.825396
# 2          150   0.117360  0.828146
# 3          200   0.117188  0.828650
# 4          250   0.116859  0.829610
# 5          300   0.116770  0.829870
# 6          350   0.116742  0.829954
# 7          400   0.116706  0.830058
# 8          500   0.116857  0.829617

# %% [markdown]
# ## XGB Regressor

# %%
import xgboost as xgb
from sklearn import metrics

xgb_summary_df = pd.DataFrame(columns=['test_RMSE', 'test_R^2'])

# Initialize and train the XGBoost Regressor model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=0)
xgb_model.fit(X_train, y_train)

# Make predictions on the test set
xgb_preds = xgb_model.predict(X_test)

# Evaluate the model using regression metrics
xgb_rmse = np.sqrt(metrics.mean_squared_error(y_test, xgb_preds))
xgb_r2 = metrics.r2_score(y_test, xgb_preds)

print(f"XGBoost Test RMSE: {xgb_rmse}")
print(f"XGBoost Test R2: {xgb_r2}")

 # Create a new row with the current Random Forest results
new_xgb_entry = {
        'test_RMSE': xgb_rmse,
        'test_R^2': xgb_r2
    }

  # Append the new entry to the summary DataFrame
xgb_summary_df = pd.concat([xgb_summary_df, pd.DataFrame([new_xgb_entry])], ignore_index=True)

  # Display the updated summary DataFrame
display(xgb_summary_df)
# Out:
# XGBoost Test RMSE: 0.1135517377642606
# XGBoost Test R2: 0.8391191993034712
# /tmp/ipykernel_322/287487622.py:27: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   xgb_summary_df = pd.concat([xgb_summary_df, pd.DataFrame([new_xgb_entry])], ignore_index=True)
#    test_RMSE  test_R^2
# 0   0.113552  0.839119

# %% [markdown]
# ##Random Forest Classifier

# %%
#Uncomment to re-initialize the summary df
classification_summary_df = pd.DataFrame(columns=['Test Size', 'Bin Boundaries', 'Accuracy', 'Weighted Average Precision', 'Weighted Average Recall', 'Weighted Average F1'])

# Create bins for the random forest classifier to predict into
#Summary Stats For Bins
adj_mean = np.round(ohe_df['yield'].mean() + 0.05,2)
adj_max = np.round(ohe_df['yield'].max(), 2) + 0.05
adj_low = np.round(adj_mean/2, 2)
adj_high = np.round(adj_mean + (-adj_mean+adj_max)/2, 2)
adj_min = 0 if ohe_df['yield'].min() >= 0 else np.round(ohe_df['yield'].min() - 0.01, 2)

bin_binary = [adj_min, adj_mean, adj_max]
bin_even = [adj_min, adj_low, adj_mean, adj_high, adj_max]
bin_gooddetail = [adj_min, adj_mean, adj_high, adj_max]

# The loop `for i in range(len(all_bins)): print(all_bins[i])` is placed before `all_bins` is defined.
# Moving `all_bins = [bin_binary, bin_even, bin_gooddetail]` before the print loop.
all_bins = [bin_binary, bin_even, bin_gooddetail]

for i in range(len(all_bins)):
  print(all_bins[i])

#Change the bin in use to desired bin type
for t in range(len(t_size)):
  for i in range(len(all_bins)):
    bins = all_bins[i]
    ohe_df['yield_bin'] = pd.cut(ohe_df['yield'], bins=bins, labels=False, include_lowest=True)
    X_bin = ohe_df.drop(columns=["yield", "yield_bin"]).values
    y_bin = ohe_df["yield_bin"].values

    # Split data into training and testing sets
    _X_train, X_test, _y_train, y_test = model_selection.train_test_split(X_bin, y_bin, test_size=t_size[t], random_state=0)
    X_train, X_valid, y_train, y_valid = model_selection.train_test_split(
        _X_train, _y_train, test_size=(0.1 / 0.7), shuffle=False
    )

    ''' # Uncomment if necessary: Check lengths
    print(X_train.shape, y_train.shape)
    print(X_valid.shape, y_valid.shape)
    print(X_test.shape, y_test.shape)
    print(len(ohe_df) == X_train.shape[0] + X_valid.shape[0] + X_test.shape[0])'''


    #Implement the Random Forest Classifier Model
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

    # Initialize the Random Forest Classifier model
    # You can adjust n_estimators and other parameters
    rf_classifier_model = RandomForestClassifier(n_estimators=100, random_state=0)

    # Train the classifier model
    rf_classifier_model.fit(X_train, y_train)

    # Make predictions on the test set
    y_bin_pred = rf_classifier_model.predict(X_test)

    # Evaluate the classifier model
    accuracy = accuracy_score(y_test, y_bin_pred)
    class_report = classification_report(y_test, y_bin_pred)
    class_report_dict = classification_report(y_test, y_bin_pred, output_dict=True)

    conf_matrix = confusion_matrix(y_test, y_bin_pred)

    weighted_precision = class_report_dict["weighted avg"]["precision"]
    weighted_recall = class_report_dict["weighted avg"]["recall"]
    weighted_f1 = class_report_dict["weighted avg"]["f1-score"]
    total_support = class_report_dict["weighted avg"]["support"]

    # Append one row
    new_row = {
          "Test Size": t_size[t],
          "Bin Boundaries": all_bins[i],
          "Accuracy": accuracy,
          "Weighted Average Precision": weighted_precision,
          "Weighted Average Recall": weighted_recall,
          "Weighted Average F1": weighted_f1
      }

    classification_summary_df = pd.concat([classification_summary_df, pd.DataFrame([new_row])], ignore_index=True)
    print(f"Random Forest Classifier Accuracy: {accuracy:.4f}")
    print("\nClassification Report:\n", class_report)
    print("\nConfusion Matrix:\n", conf_matrix)
    print("\n")

display(classification_summary_df)
# Out:
# [0, np.float64(0.45), np.float64(1.05)]
# [0, np.float64(0.22), np.float64(0.45), np.float64(0.75), np.float64(1.05)]
# [0, np.float64(0.45), np.float64(0.75), np.float64(1.05)]
# /tmp/ipykernel_322/2452796267.py:80: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   classification_summary_df = pd.concat([classification_summary_df, pd.DataFrame([new_row])], ignore_index=True)
# Random Forest Classifier Accuracy: 0.8631
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89      2402
#            1       0.84      0.82      0.83      1630
#
#     accuracy                           0.86      4032
#    macro avg       0.86      0.86      0.86      4032
# weighted avg       0.86      0.86      0.86      4032
#
#
# Confusion Matrix:
#  [[2148  254]
#  [ 298 1332]]
#
#
# Random Forest Classifier Accuracy: 0.6652
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82      1480
#            1       0.54      0.39      0.46       922
#            2       0.55      0.59      0.57       980
#            3       0.73      0.67      0.70       650
#
#     accuracy                           0.67      4032
#    macro avg       0.65      0.63      0.64      4032
# weighted avg       0.66      0.67      0.66      4032
#
#
# Confusion Matrix:
#  [[1303  127   45    5]
#  [ 304  363  246    9]
#  [  90  161  583  146]
#  [  16   16  185  433]]
#
#
# Random Forest Classifier Accuracy: 0.7696
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88      2402
#            1       0.57      0.50      0.53       980
#            2       0.73      0.64      0.69       650
#
#     accuracy                           0.77      4032
#    macro avg       0.72      0.69      0.70      4032
# weighted avg       0.76      0.77      0.76      4032
#
#
# Confusion Matrix:
#  [[2194  197   11]
#  [ 348  491  141]
#  [  55  177  418]]
#
#
# Random Forest Classifier Accuracy: 0.8795
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90      1703
#            1       0.86      0.84      0.85      1177
#
#     accuracy                           0.88      2880
#    macro avg       0.88      0.87      0.88      2880
# weighted avg       0.88      0.88      0.88      2880
#
#
# Confusion Matrix:
#  [[1539  164]
#  [ 183  994]]
#
#
# Random Forest Classifier Accuracy: 0.6927
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83      1059
#            1       0.56      0.47      0.51       644
#            2       0.60      0.61      0.60       713
#            3       0.73      0.74      0.74       464
#
#     accuracy                           0.69      2880
#    macro avg       0.67      0.67      0.67      2880
# weighted avg       0.69      0.69      0.69      2880
#
#
# Confusion Matrix:
#  [[909 120  28   2]
#  [176 304 161   3]
#  [ 43 111 438 121]
#  [  5   6 109 344]]
#
#
# Random Forest Classifier Accuracy: 0.8052
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      1703
#            1       0.64      0.55      0.59       713
#            2       0.75      0.74      0.74       464
#
#     accuracy                           0.81      2880
#    macro avg       0.75      0.74      0.75      2880
# weighted avg       0.80      0.81      0.80      2880
#
#
# Confusion Matrix:
#  [[1583  115    5]
#  [ 209  393  111]
#  [  17  104  343]]
#
#
# Random Forest Classifier Accuracy: 0.9016
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92      1004
#            1       0.89      0.87      0.88       724
#
#     accuracy                           0.90      1728
#    macro avg       0.90      0.90      0.90      1728
# weighted avg       0.90      0.90      0.90      1728
#
#
# Confusion Matrix:
#  [[928  76]
#  [ 94 630]]
#
#
# Random Forest Classifier Accuracy: 0.7303
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85       638
#            1       0.60      0.57      0.58       366
#            2       0.65      0.65      0.65       444
#            3       0.75      0.79      0.77       280
#
#     accuracy                           0.73      1728
#    macro avg       0.71      0.71      0.71      1728
# weighted avg       0.73      0.73      0.73      1728
#
#
# Confusion Matrix:
#  [[546  71  20   1]
#  [ 80 207  77   2]
#  [ 18  66 289  71]
#  [  2   2  56 220]]
#
#
# Random Forest Classifier Accuracy: 0.8206
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1004
#            1       0.69      0.59      0.64       444
#            2       0.76      0.75      0.76       280
#
#     accuracy                           0.82      1728
#    macro avg       0.78      0.76      0.77      1728
# weighted avg       0.81      0.82      0.82      1728
#
#
# Confusion Matrix:
#  [[946  56   2]
#  [118 262  64]
#  [  8  62 210]]
#    Test Size               Bin Boundaries  Accuracy  \
# 0        0.7              [0, 0.45, 1.05]  0.863095
# 1        0.7  [0, 0.22, 0.45, 0.75, 1.05]  0.665179
# 2        0.7        [0, 0.45, 0.75, 1.05]  0.769593
# 3        0.5              [0, 0.45, 1.05]  0.879514
# 4        0.5  [0, 0.22, 0.45, 0.75, 1.05]  0.692708
# 5        0.5        [0, 0.45, 0.75, 1.05]  0.805208
# 6        0.3              [0, 0.45, 1.05]  0.901620
# 7        0.3  [0, 0.22, 0.45, 0.75, 1.05]  0.730324
# 8        0.3        [0, 0.45, 0.75, 1.05]  0.820602
#
#    Weighted Average Precision  Weighted Average Recall  Weighted Average F1
# 0                    0.862677                 0.863095             0.862780
# 1                    0.655177                 0.665179             0.655367
# 2                    0.759475                 0.769593             0.762756
# 3                    0.879281                 0.879514             0.879358
# 4                    0.685913                 0.692708             0.688047
# 5                    0.796818                 0.805208             0.799665
# 6                    0.901457                 0.901620             0.901438
# 7                    0.728030                 0.730324             0.728993
# 8                    0.813173                 0.820602             0.815320

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix for Random Forest Classifier')
plt.xlabel('Predicted Bin')
plt.ylabel('True Bin')
plt.show()
